# %% [markdown]
# # Test for the program

# %% [markdown]
# We use three locations to test whether this project works well. The first two locations are 'Paris Las Vegas' hotel and 'The D Las Vegas' hotel, and we successfully find restaurants around them. We then test the "Nanjing University" in China, because we cannot find restaurants in Las Vegas arond the location , it outputs 'Oops, there is no such restaurant near you :('.

# %%
import os
import json
import requests
import Visualization #The moduel we code for map visualization
from Dinner_Function import dinner #The moduel we code for restaurants selection

def what_for_dinner(person_address,radius=500):
    
    #Get formatted_address
    address = person_address.replace(' ','+')+'+Las+Vegas'
    response = requests.get('https://maps.googleapis.com/maps/api/geocode/json?address=%s&key=AIzaSyBmpmNHzWutfb5CY7K3PeZZbvU4KAld3rM'%address)
    resp_json_payload = response.json()

    formatted_address = resp_json_payload['results'][0]['formatted_address']
    print('The formatted address of your current location:',formatted_address)
    
    #Get latitude and longitude
    person_site = [resp_json_payload['results'][0]['geometry']['location']['lat'],
              resp_json_payload['results'][0]['geometry']['location']['lng']]
    
    #Import clusters data
    with open('data/clusters.json','rb') as clusters_init:
        clusters_data = json.loads(clusters_init.read())
        
    #import clusters center
    with open('data/clusters_centers.json','rb') as clusters_coordinates:
        clusters_coordinates = json.loads(clusters_coordinates.read())
        
    results = dinner(person_site,clusters_coordinates, clusters_data,radius)
    m = Visualization.ResultsVisualization(results,formatted_address) 
    try:
        m.save(os.path.join('img-storage','restaurants_around_%s.html'%person_address))
    except:
        return('Oops, we cannot find restaurants for you :(')
    return m

# %% [markdown]
# ## 'Paris Las Vegas' Hotel, distance is 1000 meters

# %% [markdown]
# Input address and radius

# %%
address = 'Paris Las Vegas'
radius = 1000

# %%
what_for_dinner(address,radius)
# Out:
# The formatted address of your current location: 3655 S Las Vegas Blvd, Las Vegas, NV 89109, USA
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 'The D Las Vegas' Hotel, distance is 1200 meters

# %%
address = 'The D Las Vegas'
radius = 1200

# %%
what_for_dinner(address,radius)
# Out:
# The formatted address of your current location: 301 Fremont St, Las Vegas, NV 89101, USA
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Search for 'Nanjing University' (China), distance is 1200 meters

# %%
address = 'Nanjing University'
radius = 1200

# %%
what_for_dinner(address,radius)
# Out:
# The formatted address of your current location: 22 Hankou Rd, Gulou Qu, Nanjing Shi, Jiangsu Sheng, China, 210008
# 'Oops, we cannot find restaurants for you :('

# %% [markdown]
# <b>Nanjing University is in China, therefore we obsolutely can not find restaurants around the location your input.
