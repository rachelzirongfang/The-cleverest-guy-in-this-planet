# %% [markdown]
# # What for dinner in Las Vegas

# %%
import json
from Dinner_Function import dinner
import Visualization
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/a2/fb/7a7af9ef7a35d16fa23b127abee272cfc483ca89029b73e92e93cdf36e6b/Shapely-1.6.4.post2.tar.gz
#     Complete output from command python setup.py egg_info:
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\Zeguan\AppData\Local\Temp\pip-install-c4pjxab2\shapely\setup.py", line 80, in <module>
#         from shapely._buildcfg import geos_version_string, geos_version, \
#       File "C:\Users\Zeguan\AppData\Local\Temp\pip-install-c4pjxab2\shapely\shapely\_buildcfg.py", line 200, in <module>
#         lgeos = CDLL("geos_c.dll")
#       File "D:\Programs\Anaconda3\lib\ctypes\__init__.py", line 348, in __init__
#         self._handle = _dlopen(self._name, mode)
#     OSError: [WinError 126] The specified module could not be found
#
#     ----------------------------------------
# ...

# %% [markdown]
# <h3>Input your location

# %%
person_address = input('Input your current address:')
radius = input('Input your preferred distance range(defalt=500 meters):')

# %% [markdown]
# <h4>The detail information of current address

# %%
import requests
address = person_address.replace(' ','+')
response = requests.get('https://maps.googleapis.com/maps/api/geocode/json?address=%s&key=AIzaSyBmpmNHzWutfb5CY7K3PeZZbvU4KAld3rM'%address)
resp_json_payload = response.json()

detail_address = resp_json_payload['results'][0]['formatted_address']
print('The formatted address of your current location:',detail_address)
# Out:
# The formatted address of your current location: 3655 S Las Vegas Blvd, Las Vegas, NV 89109, USA

# %%
person_site = [resp_json_payload['results'][0]['geometry']['location']['lat'],
              resp_json_payload['results'][0]['geometry']['location']['lng']]

# %% [markdown]
# <h3>Show the restaurants with rating above 4 around you

# %%
def what_for_dinner(person_site,radius=500):
    
    #Import clusters data
    with open('clusters.json','rb') as clusters_init:
        clusters_data = json.loads(clusters_init.read())
        
    #import clusters center
    with open('clusters_centers.json','rb') as clusters_coordinates:
        clusters_coordinates = json.loads(clusters_coordinates.read())
        
    results = dinner(person_site,clusters_coordinates, clusters_data,radius)
    return Visualization.ResultsVisualization(results)

# %%
what_for_dinner(person_site)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
