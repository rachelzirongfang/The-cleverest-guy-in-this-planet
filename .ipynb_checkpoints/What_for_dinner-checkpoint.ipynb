# %% [markdown]
# Inport your location

# %%
# !pip install geopy --upgrade
# Out:
# Collecting geopy
#   Downloading https://files.pythonhosted.org/packages/f3/b4/c8842fc6a07fc95d6887370768850885382b47bf52f5cd8b6a4ae1b6f4d9/geopy-1.17.0-py2.py3-none-any.whl (92kB)
# Collecting geographiclib<2,>=1.49 (from geopy)
#   Downloading https://files.pythonhosted.org/packages/5b/ac/4f348828091490d77899bc74e92238e2b55c59392f21948f296e94e50e2b/geographiclib-1.49.tar.gz
# Building wheels for collected packages: geographiclib
#   Running setup.py bdist_wheel for geographiclib: started
#   Running setup.py bdist_wheel for geographiclib: finished with status 'done'
#   Stored in directory: C:\Users\Zeguan\AppData\Local\pip\Cache\wheels\99\45\d1\14954797e2a976083182c2e7da9b4e924509e59b6e5c661061
# Successfully built geographiclib
# Installing collected packages: geographiclib, geopy
# Successfully installed geographiclib-1.49 geopy-1.17.0
# You are using pip version 10.0.1, however version 18.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
import json
from Dinner_Function import dinner
#Import clusters data
with open('clusters.json','rb') as clusters_init:
    clusters_data = json.loads(clusters_init.read())
#import clusters center
with open('clusters_centers.json','rb') as clusters_coordinates:
    clusters_coordinates = json.loads(clusters_coordinates.read())

# %%
person_address = input('Input your location:')

# %%
person_address
# Out:
# 'The Venetian, Las Vegas'

# %%
import requests
address = person_address.replace(' ','+')
response = requests.get('https://maps.googleapis.com/maps/api/geocode/json?address=%s&key=AIzaSyBmpmNHzWutfb5CY7K3PeZZbvU4KAld3rM'%address)
resp_json_payload = response.json()

person_site = [resp_json_payload['results'][0]['geometry']['location']['lat'],
              resp_json_payload['results'][0]['geometry']['location']['lng']]

# %%
def dinner(person_site, clusters_coordinates, clusters_data, radius=500):
    import json
    
    p_lati = person_site[0]
    p_long = person_site[1]
    
    
    """
    Here will be a function to determine whether the person is in Las Vegas
    """
    
    """
    For Las Vegas area, we use 1 degree latitude = 111km and 1 degree longitude = 90km
    """
    d_lati = 0.01801801801/4*radius/500 #0.01801801801/4 is unit degree of latitude for 500 meters
    d_long = 0.02222222222/4*radius/500 #0.02222222222/4 is unit degree of longitude for 500 meters
    
    
    k_num = len(clusters_data)
    k_distance = 100000000
    k_count = 0
    k_count_nd = 0
    k_distance_90=[]
    
    # below calculate 90 percent quantile
    for i in range(len(clusters_data)):
        k_distance_ls = []
        for rstrt in clusters_data[i]:
            k_distance_ls.append((rstrt['latitude'] - clusters_coordinates[i][0])*(rstrt['latitude'] - clusters_coordinates[i][0]) + (rstrt['longitude'] - clusters_coordinates[i][1])*(rstrt['longitude'] - clusters_coordinates[i][1]))
        k_distance_90.append(sorted(k_distance_ls)[int(0.9*len(k_distance_ls))])
    
    # below to get the closest cluster
    for i in range(k_num):
        if (p_lati - clusters_coordinates[i][0])*(p_lati - clusters_coordinates[i][0]) + (p_long - clusters_coordinates[i][1])*(p_long - clusters_coordinates[i][1]) < min(k_distance,k_distance_90[i]):
            k_distance = k_distance_90[i]
            k_count = i
    
    # below to loop over the closest cluster
    rstrt_ls=[[p_lati,p_long]]
    for rstrt in clusters_data[k_count]:
        if abs(p_lati - rstrt['latitude'])<d_lati and abs(p_long - rstrt['longitude'])<d_long:
            if 'stars' in rstrt.keys():
                if rstrt['stars']>=4:
                    rstrt_ls.append(rstrt)
    
    
    if len(rstrt_ls) == 1:
        # below to get the 2nd closest cluster
        k_count_nd = 0
        for i in [elem for elem in range(k_num) if elem != k_count]:
            if (p_lati - clusters_coordinates[i][0])*(p_lati - clusters_coordinates[i][0]) + (p_long - clusters_coordinates[i][1])*(p_long - clusters_coordinates[i][1]) < min(k_distance,k_distance_90[i]):
                k_distance = k_distance_90[i]
                k_count_nd = i
        # try to loop over the 2nd closest cluster
        for rstrt in clusters_data[k_count_nd]:
            if abs(p_lati - rstrt['latitude'])<d_lati and abs(p_long - rstrt['longitude'])<d_long:
                rstrt_ls.append(rstrt)
    
    if len(rstrt_ls) != 1:
        with open('clusters_final.json', 'w') as f:
            json.dump(rstrt_ls, f)
    else:
        return("Oops, there is no such restaurant near you :(")
    return rstrt_ls

# %%
results = dinner(person_site,clusters_coordinates, clusters_data)

# %%
results
# Out:
# [[36.121174, -115.1696526],
#  {'name': 'Center Bar',
#   'address': '3400 Las Vegas Blvd S',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1212601526,
#   'longitude': -115.174520771,
#   'stars': 4.0,
#   'categories': 'Vacation Rentals, Lounges, Nightlife, Sports Bars, Bars, Hotels & Travel',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Godiva Chocolatier #344',
#   'address': '3377 Las Vegas Blvd S',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1220145,
#   'longitude': -115.1696491,
#   'stars': 4.0,
#   'categories': 'Food, Specialty Food',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Il Mulino New York',
#   'address': '3500 Las Vegas Blvd S, Ste T30',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.119468,
#   'longitude': -115.173077,
#   'stars': 4.0,
#   'categories': 'Restaurants, Italian',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Gordon Ramsay Fish & Chips',
#   'address': '3545 Las Vegas Blvd S',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.117337,
#   'longitude': -115.171803,
#   'stars': 4.0,
#   'categories': 'Comfort Food, Restaurants, Fish & Chips, Seafood',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Bella Panini',
#   'address': 'The Venetian Resort Hotel Casino, 3377 Las Vegas Blvd. South',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.121558,
#   'longitude': -115.169758,
#   'stars': 4.0,
#   'categories': 'Restaurants, Sandwiches',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Yofresco',
#   'address': '3377 Las Vegas Blvd, Ste 2130',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1218691,
#   'longitude': -115.1696529,
#   'stars': 4.5,
#   'categories': 'Food, Ice Cream & Frozen Yogurt',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Sin City Brewing Company',
#   'address': '3377 Las Vegas Blvd S',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.121469,
#   'longitude': -115.169102,
#   'stars': 4.0,
#   'categories': 'Food, Breweries, Bars, Nightlife',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Bouchon Bakery at the Venetian Theater',
#   'address': '3355 Las Vegas Blvd S, Venetian Theater, Sports Book and Clock Tower',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.12291,
#   'longitude': -115.170716,
#   'stars': 4.0,
#   'categories': 'Restaurants, Bakeries, Desserts, French, Sandwiches, Food',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Snack Nook',
#   'address': '3411 Las Vegas Blvd',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1203829,
#   'longitude': -115.17132,
#   'stars': 4.0,
#   'categories': 'Restaurants, Fast Food',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Anchor Bar',
#   'address': 'The Venetian - Food Ct, 3377 Las Vegas Blvd So',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1218632,
#   'longitude': -115.1696491,
#   'stars': 4.0,
#   'categories': 'Chicken Wings, Restaurants',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Tag Bar',
#   'address': '3535 Las Vegas Blvd',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1176304946,
#   'longitude': -115.172318369,
#   'stars': 4.0,
#   'categories': 'Sports Bars, Nightlife, Bars',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Rattlecan',
#   'address': '3355 S Las Vegas Blvd',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1226902,
#   'longitude': -115.1701939,
#   'stars': 4.0,
#   'categories': 'Restaurants, Burgers',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Blvd. Cocktail Company',
#   'address': '3535 Las Vegas Blvd',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1182919,
#   'longitude': -115.170409,
#   'stars': 4.0,
#   'categories': 'Bars, Nightlife, Cocktail Bars',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Fusion Mixology Bar',
#   'address': '3325 S Las Vegas Blvd',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1242284,
#   'longitude': -115.1684696,
#   'stars': 4.0,
#   'categories': 'Bars, Nightlife',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'La Scena Lounge',
#   'address': '3355 S Las Vegas Blvd',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.122371,
#   'longitude': -115.169573,
#   'stars': 4.0,
#   'categories': 'Bars, Nightlife',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'The Grill At Valentino',
#   'address': '3355 Las Vegas Blvd',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1226902,
#   'longitude': -115.1701939,
#   'stars': 4.0,
#   'categories': 'Italian, Restaurants',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': "Ruth's Chris Steak House",
#   'address': "Harrah's Las Vegas Hotel & Casino, 3475 Las Vegas Boulevard South",
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1195756555,
#   'longitude': -115.17219718,
#   'stars': 4.0,
#   'categories': 'Restaurants, Seafood, Steakhouses',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Espresso Culture & Cuisine',
#   'address': '3448-3470 S Las Vegas Blvd',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1192765,
#   'longitude': -115.1727528,
#   'stars': 4.0,
#   'categories': 'Gelato, Food, Coffee & Tea, Desserts',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'The Paiza Club',
#   'address': '3355 Las Vegas Blvd S',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1226902,
#   'longitude': -115.1701939,
#   'stars': 5.0,
#   'categories': 'Casinos, Arts & Entertainment, Restaurants, Asian Fusion',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Haagen Dazs Shop',
#   'address': 'The Venetian Hotel & Casino, 3377 S Las Vegas Blvd, Ste 2260',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1218632,
#   'longitude': -115.1696491,
#   'stars': 4.0,
#   'categories': 'Food, Juice Bars & Smoothies, Ice Cream & Frozen Yogurt',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Vosges Haut-Chocolat',
#   'address': '3500 Las Vegas Blvd S',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1183321618,
#   'longitude': -115.174350385,
#   'stars': 4.5,
#   'categories': 'Ice Cream & Frozen Yogurt, Food, Coffee & Tea, Chocolatiers & Shops, Specialty Food',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Carnaval Wine & Spirits',
#   'address': '3475 Las Vegas Blvd S',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.11949,
#   'longitude': -115.169667,
#   'stars': 4.0,
#   'categories': 'Food, Nightlife, Beer, Wine & Spirits',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Honolulu Cookie Company - Grand Canal Shoppes',
#   'address': '3327 Las Vegas Blvd S',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1240615,
#   'longitude': -115.167872,
#   'stars': 4.5,
#   'categories': 'Food, Bakeries, Desserts',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Canyon Ranch Grill',
#   'address': '3355 Las Vegas Blvd S, Fl 3',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1237193244,
#   'longitude': -115.167797904,
#   'stars': 4.0,
#   'categories': 'Breakfast & Brunch, American (New), American (Traditional), Restaurants',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Sushi Roku',
#   'address': "Forum Shops Caesar's Palace, 3500 Las Vegas Blvd S, Ste T18",
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.118966,
#   'longitude': -115.17305,
#   'stars': 4.0,
#   'categories': 'Japanese, Lounges, Sushi Bars, Nightlife, Bars, Restaurants',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': "P.J. Clarke's New York Chophouse",
#   'address': 'The Forum Shops At Caesars Palace, 3500 S Las Vegas Blvd',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.118399,
#   'longitude': -115.172945,
#   'stars': 4.0,
#   'categories': 'Gastropubs, American (New), Steakhouses, Seafood, Restaurants',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Nosh Las Vegas',
#   'address': '',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1219055072,
#   'longitude': -115.173876382,
#   'stars': 4.5,
#   'categories': 'Hotels & Travel, Food Tours, Tours',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Paris Baguette',
#   'address': '3377 Las Vegas Blvd, Ste 2390',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1218691,
#   'longitude': -115.1696529,
#   'stars': 4.0,
#   'categories': 'Bakeries, Coffee & Tea, Cafes, Food, Restaurants',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Mercato Della Pescheria',
#   'address': '3377 S Las Vegas Blvd, Ste 2410',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.122676,
#   'longitude': -115.168935,
#   'stars': 4.0,
#   'categories': 'Restaurants, Seafood, Pizza, Mediterranean, Modern European, Italian',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Canonita',
#   'address': '3377 Las Vegas Blvd, The Venetian® and The Palazzo®, Venetian Hotel',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.121876,
#   'longitude': -115.168764,
#   'stars': 4.0,
#   'categories': 'Restaurants, Tacos, Mexican, Tex-Mex',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Gondola Bar',
#   'address': '3355 S Las Vegas Blvd',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1226902,
#   'longitude': -115.1701939,
#   'stars': 5.0,
#   'categories': 'Nightlife, Bar Crawl, Bars',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': '3535 Bar',
#   'address': 'The Linq, 3535 Las Vegas Blvd S, The Linq',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1181654,
#   'longitude': -115.1706363,
#   'stars': 4.0,
#   'categories': 'Cocktail Bars, Lounges, Nightlife, Bars',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'BAZ Las Vegas',
#   'address': '3325 S Las Vegas Blvd',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1242284,
#   'longitude': -115.1684696,
#   'stars': 4.5,
#   'categories': 'Arts & Entertainment, Nightlife, Performing Arts, Cabaret',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Mesa Grill',
#   'address': '3570 Las Vegas Blvd S',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1171245659,
#   'longitude': -115.174792707,
#   'stars': 4.0,
#   'categories': 'Southern, American (New), Tex-Mex, Mexican, Restaurants, New Mexican Cuisine, American (Traditional)',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Squeeze',
#   'address': '3545 Las Vegas Blvd S',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1176611,
#   'longitude': -115.1727833,
#   'stars': 4.5,
#   'categories': 'Bars, Nightlife, Food, Cocktail Bars, Juice Bars & Smoothies',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'SUGARCANE Raw Bar Grill',
#   'address': '3355 Las Vegas Blvd S, Ste 112',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1226902,
#   'longitude': -115.1701939,
#   'stars': 4.0,
#   'categories': 'Restaurants, American (New), Coffee & Tea, Nightlife, Cocktail Bars, Tapas Bars, Desserts, Tapas/Small Plates, American (Traditional), Bars, Wine Bars, Food',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Rosina',
#   'address': '3325 S Las Vegas Blvd',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1242284,
#   'longitude': -115.1684696,
#   'stars': 4.0,
#   'categories': 'Cocktail Bars, Nightlife, Bars',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Krispy Kreme',
#   'address': '3377 S Las Vegas Blvd',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1218632,
#   'longitude': -115.1696491,
#   'stars': 4.0,
#   'categories': 'Donuts, Food',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Jaburritos',
#   'address': '3535 S Las Vegas Blvd',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1175754745,
#   'longitude': -115.170291604,
#   'stars': 4.5,
#   'categories': 'Restaurants, Sushi Bars, Seafood, Japanese, Asian Fusion, Mexican',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Old Homestead Steakhouse',
#   'address': '3570 Las Vegas Blvd S',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1169221843,
#   'longitude': -115.175010956,
#   'stars': 4.0,
#   'categories': 'Steakhouses, Restaurants',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': "Grimaldi's Pizzeria",
#   'address': '3327 Las Vegas Blvd S, Ste 2710',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1248767264,
#   'longitude': -115.169034004,
#   'stars': 4.0,
#   'categories': 'Restaurants, Pizza',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': "Carmine's Italian Restaurant - Las Vegas",
#   'address': '3500 S Las Vegas Blvd',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1193209467,
#   'longitude': -115.175200447,
#   'stars': 4.0,
#   'categories': 'Venues & Event Spaces, Event Planning & Services, Restaurants, Food, Italian, Salad, Desserts, Caterers, Seafood',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Ghirardelli Ice Cream and Chocolate Shop',
#   'address': "Harrah's Carnaval Court, 3475 Las Vegas Blvd S",
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1193098,
#   'longitude': -115.1717702,
#   'stars': 4.0,
#   'categories': 'Desserts, Specialty Food, Food, Chocolatiers & Shops, Ice Cream & Frozen Yogurt, Restaurants',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': "Buddy V's Ristorante",
#   'address': '3327 S Las Vegas Blvd',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.123406,
#   'longitude': -115.170188,
#   'stars': 4.0,
#   'categories': 'American (Traditional), Italian, Restaurants',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Double Helix Wine & Whiskey Bar',
#   'address': '3327 Las Vegas Blvd S, Fl 2, Palazzo Hotel Grand Canal Shoppes',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1240615,
#   'longitude': -115.167872,
#   'stars': 4.0,
#   'categories': 'Food, Whiskey Bars, Wine Bars, Nightlife, Beer, Wine & Spirits, Bars',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Le Macaron Venetian',
#   'address': '3377 S Las Vegas Blvd, Unit 2353',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1218691,
#   'longitude': -115.1696529,
#   'stars': 4.0,
#   'categories': 'Champagne Bars, Bakeries, Coffee & Tea, Specialty Food, Nightlife, Macarons, Food, Bars',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Teavana',
#   'address': '3377 S Las Vegas Blvd',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1226036,
#   'longitude': -115.1710908,
#   'stars': 4.5,
#   'categories': 'Coffee & Tea, Food',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Truefitt & Hill',
#   'address': '3500 Las Vegas Blvd S',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1183949,
#   'longitude': -115.1729418,
#   'stars': 4.5,
#   'categories': 'Barbers, Beauty & Spas',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Kahunaville O2 Bar',
#   'address': '3300 Las Vegas Blvd S',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1250660251,
#   'longitude': -115.172832347,
#   'stars': 4.5,
#   'categories': 'Massage, Beauty & Spas, Lounges, Bars, Nightlife',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'The Coffee Bean & Tea Leaf',
#   'address': '3377 S. Las Vegas Blvd, Suite 2164 B',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1230543,
#   'longitude': -115.1707759,
#   'stars': 5.0,
#   'categories': 'Food, Coffee & Tea',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Pinot Brasserie Bakery',
#   'address': '3355 Las Vegas Blvd S',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1226902,
#   'longitude': -115.1701939,
#   'stars': 4.0,
#   'categories': 'Food, Restaurants, French, Coffee & Tea',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Yardbird Southern Table & Bar',
#   'address': '3355 Las Vegas Blvd S',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1223280185,
#   'longitude': -115.170111843,
#   'stars': 4.5,
#   'categories': 'Southern, Restaurants, American (New)',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Margarita Bar',
#   'address': '3300 S Las Vegas Blvd',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.124013,
#   'longitude': -115.170688,
#   'stars': 4.0,
#   'categories': 'Food, Beer, Wine & Spirits',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'AquaKnox',
#   'address': 'The Venetian Hotel Resort Casino 3355 Las Vegas Blvd',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.12300032,
#   'longitude': -115.169071769,
#   'stars': 4.0,
#   'categories': 'Food, Nightlife, Bars, Seafood, Lounges, Steakhouses, Live/Raw Food, Bakeries, Restaurants',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Tsunami Asian Grill & Sushi Bar',
#   'address': 'Venetian Hotel, 3355 Las Vegas Blvd S',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1214517,
#   'longitude': -115.1696112,
#   'stars': 4.5,
#   'categories': 'Japanese, Korean, Chinese, Thai, Sushi Bars, Restaurants, Vietnamese',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Grand Lux Cafe',
#   'address': '3327 Las Vegas Blvd S, Ste 1580',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1218602707,
#   'longitude': -115.168944884,
#   'stars': 4.0,
#   'categories': 'Restaurants, Seafood, American (New), Barbeque, American (Traditional), Food, Desserts',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Grand Lux Cafe',
#   'address': '3355 Las Vegas Blvd S',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.121822,
#   'longitude': -115.168855,
#   'stars': 4.0,
#   'categories': 'Sandwiches, American (Traditional), Food, American (New), Restaurants, Desserts',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Oyster Bar',
#   'address': '3475 S Las Vegas Blvd',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1193098,
#   'longitude': -115.1717702,
#   'stars': 4.0,
#   'categories': 'Seafood, Restaurants, Live/Raw Food, Italian',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Yard House',
#   'address': '3545 Las Vegas Blvd',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1175416594,
#   'longitude': -115.168661512,
#   'stars': 4.0,
#   'categories': 'American (New), Asian Fusion, Restaurants, Vegetarian, American (Traditional), Nightlife, Cocktail Bars, Steakhouses, Wine Bars, Seafood, Beer Bar, Bars',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'The Art of Shaving',
#   'address': '3500 Las Vegas Blvd SO, Space 0E21',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1186529353,
#   'longitude': -115.17433905,
#   'stars': 4.0,
#   'categories': 'Cosmetics & Beauty Supply, Beauty & Spas, Shopping, Barbers',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Art of Shaving',
#   'address': '3355 Las Vegas Blvd S',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1243396763,
#   'longitude': -115.167767081,
#   'stars': 4.0,
#   'categories': 'Beauty & Spas, Barbers',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Fat Tuesday',
#   'address': '3411 Las Vegas Blvd',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1206696,
#   'longitude': -115.17168,
#   'stars': 4.0,
#   'categories': 'Nightlife, Bars',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Diamond Lounge at Harrahs',
#   'address': 'Harrahs Casino',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1194645,
#   'longitude': -115.1716391,
#   'stars': 4.5,
#   'categories': 'Nightlife, Bars, Lounges',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Trattoria Reggiano',
#   'address': '3355 Las Vegas Blvd S',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.121929,
#   'longitude': -115.168416,
#   'stars': 4.0,
#   'categories': 'Restaurants, Italian',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Clint Holmes - Between The Lines',
#   'address': '3325 S Las Vegas Blvd',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1242284,
#   'longitude': -115.1684696,
#   'stars': 5.0,
#   'categories': 'Arts & Entertainment, Performing Arts, Cabaret',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Breathe Oxygen Bar',
#   'address': '3377 S Las Vegas Blvd',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1243705,
#   'longitude': -115.169416,
#   'stars': 4.0,
#   'categories': 'Beauty & Spas, Oxygen Bars, Health & Medical, Day Spas',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Casa Fuente Cigars',
#   'address': '3500 Las Vegas Blvd S',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1194066571,
#   'longitude': -115.174189579,
#   'stars': 4.0,
#   'categories': 'Shopping, Bars, Tobacco Shops, Nightlife',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Chicke Now',
#   'address': '3700-3734 Koval Ln',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1219516351,
#   'longitude': -115.166486518,
#   'stars': 4.0,
#   'categories': 'Chicken Shop, American (New), Restaurants',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'VOM FASS Las Vegas',
#   'address': '3377 Las Vegas Blvd, Ste 2035',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1220145,
#   'longitude': -115.1696504,
#   'stars': 4.0,
#   'categories': 'Food, Herbs & Spices, Specialty Food, Beer, Wine & Spirits',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'The Range Steakhouse',
#   'address': 'Harrahs Las Vegas, 3475 S Las Vegas Blvd',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1183787,
#   'longitude': -115.1726202,
#   'stars': 4.0,
#   'categories': 'Steakhouses, Seafood, Restaurants',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Ice Pan',
#   'address': '3475 Las Vegas Blvd S, Fl 2',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1193098,
#   'longitude': -115.1717702,
#   'stars': 4.5,
#   'categories': 'Food, Ice Cream & Frozen Yogurt',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Hash House A Go Go',
#   'address': '3535 Las Vegas Blvd',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1181806906,
#   'longitude': -115.171579781,
#   'stars': 4.0,
#   'categories': 'Breakfast & Brunch, American (New), Restaurants',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'The Art of Shaving',
#   'address': '3377 Las Vegas Blvd, Ste 2380',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1227320996,
#   'longitude': -115.16886474,
#   'stars': 4.5,
#   'categories': 'Shopping, Cosmetics & Beauty Supply, Barbers, Beauty & Spas',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Once',
#   'address': '3327 S Las Vegas Blvd',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1249493045,
#   'longitude': -115.167991295,
#   'stars': 4.5,
#   'categories': 'Peruvian, Asian Fusion, Latin American, Restaurants, Japanese',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Bouchon at the Venezia Tower',
#   'address': '3355 Las Vegas Blvd S, Venezia Tower, 10th floor',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1209554593,
#   'longitude': -115.169853249,
#   'stars': 4.0,
#   'categories': 'Bakeries, Breakfast & Brunch, Food, French, Venues & Event Spaces, Cafes, Event Planning & Services, Restaurants',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Ghirardelli Ice Cream & Chocolate Shop',
#   'address': '3545 S Las Vegas Blvd',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1176550639,
#   'longitude': -115.16984346,
#   'stars': 4.0,
#   'categories': 'Food, Ice Cream & Frozen Yogurt, Specialty Food, Chocolatiers & Shops',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'TAG Sports Bar',
#   'address': '3535 South Las Vegas Blvd',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1181654,
#   'longitude': -115.1706363,
#   'stars': 4.0,
#   'categories': 'Nightlife, Bars, Sports Bars',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Urban Turban Express',
#   'address': '3545 The Linq Promenade',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1177189,
#   'longitude': -115.1679438,
#   'stars': 4.0,
#   'categories': 'Vegetarian, Halal, Indian, Restaurants',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Sprinkles Cupcakes and Ice Cream',
#   'address': '3545 S Las Vegas Blvd',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.117485,
#   'longitude': -115.169832,
#   'stars': 4.0,
#   'categories': 'Food, Cupcakes, Bakeries, Ice Cream & Frozen Yogurt',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Honolulu Cookie Company - The LINQ Promenade',
#   'address': '3545 Las Vegas Blvd S, Space L21',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1177747,
#   'longitude': -115.1725759,
#   'stars': 5.0,
#   'categories': 'Flowers & Gifts, Bakeries, Chocolatiers & Shops, Shopping, Desserts, Food, Specialty Food, Gift Shops',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Dolphin Bar',
#   'address': '3400 Las Vegas Blvd S',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1212806702,
#   'longitude': -115.172286987,
#   'stars': 4.0,
#   'categories': 'Lounges, Local Flavor, Nightlife, Bars, Food, Beer, Wine & Spirits, Hotels & Travel',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'CUT by Wolfgang Puck',
#   'address': '3325 S Las Vegas Blvd',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.123559,
#   'longitude': -115.16841,
#   'stars': 4.0,
#   'categories': 'Bars, Nightlife, Restaurants, Lounges, Steakhouses',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Apothecary',
#   'address': '3327 Las Vegas Blvd S',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1240615,
#   'longitude': -115.167872,
#   'stars': 4.5,
#   'categories': 'Barbers, Beauty & Spas',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Amorino Gelato',
#   'address': '3545 Las Vegas Blvd, Ste 3',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1177747,
#   'longitude': -115.1725759,
#   'stars': 4.5,
#   'categories': 'Macarons, Specialty Food, Food, Ice Cream & Frozen Yogurt, Desserts, Gelato',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'THE ATRIUM PALAZZO',
#   'address': '3325 South Las Vegas Blvd, Casino Floor',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1234747403,
#   'longitude': -115.168791265,
#   'stars': 4.0,
#   'categories': 'Shopping, Watches, Beer, Wine & Spirits, Beauty & Spas, Cosmetics & Beauty Supply, Food',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'In-N-Out Burger',
#   'address': '3545 S Las Vegas Blvd, Ste L24',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1174214,
#   'longitude': -115.1701669,
#   'stars': 4.0,
#   'categories': 'Restaurants, Burgers, Fast Food',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'The Dorsey',
#   'address': '3377 S Las Vegas Blvd',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1222206958,
#   'longitude': -115.170660139,
#   'stars': 4.0,
#   'categories': 'Cocktail Bars, Lounges, Nightlife, Bars',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Venetian Gold Lounge',
#   'address': '3355 S Las Vegas Blvd',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1229174,
#   'longitude': -115.1685253,
#   'stars': 4.0,
#   'categories': 'Nightlife, Lounges, Bars',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Primeburger',
#   'address': '3355 Las Vegas Blvd S',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1215171967,
#   'longitude': -115.168499606,
#   'stars': 4.0,
#   'categories': 'American (New), Burgers, Restaurants, Breakfast & Brunch',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': "ROYCE' Las Vegas at The Grand Canal Shoppes",
#   'address': '3377 S Las Vegas Blvd',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1218691,
#   'longitude': -115.1696529,
#   'stars': 5.0,
#   'categories': 'Food, Chocolatiers & Shops, Specialty Food, Desserts, Candy Stores',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Chica',
#   'address': '3355 South Las Vegas Blvd, Ste 106',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1226902,
#   'longitude': -115.1701939,
#   'stars': 4.5,
#   'categories': 'Mexican, Restaurants, Bars, Nightlife, Latin American, Wine Bars',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'SUSHISAMBA - Las Vegas',
#   'address': '3327 Las Vegas Blvd S',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1245818974,
#   'longitude': -115.167552877,
#   'stars': 4.0,
#   'categories': 'Chinese, Japanese, Nightlife, Dim Sum, Asian Fusion, Restaurants, Bars, Breakfast & Brunch',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Border Grill',
#   'address': '3500 Las Vegas Blvd S',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.119371,
#   'longitude': -115.173715,
#   'stars': 4.5,
#   'categories': 'Seafood, Restaurants, Tapas/Small Plates, Mexican, Breakfast & Brunch',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Casanova',
#   'address': '3377 S Las Vegas Blvd, Ste 2170',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1215792268,
#   'longitude': -115.168663859,
#   'stars': 4.0,
#   'categories': 'Italian, Restaurants, Mediterranean, Tapas Bars',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': "5 O'clock Somewhere Bar",
#   'address': '3555 Las Vegas Blvd S',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.116671584,
#   'longitude': -115.172661214,
#   'stars': 4.0,
#   'categories': 'Nightlife, Bars',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Buffet of Buffets',
#   'address': '3570 S Las Vegas Blvd',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1178982101,
#   'longitude': -115.174959838,
#   'stars': 4.0,
#   'categories': 'Restaurants, Buffets',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Stack Restaurant & Bar',
#   'address': 'Mirage Hotel & Casino, 3400 Las Vegas Blvd S',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1217103886,
#   'longitude': -115.174189072,
#   'stars': 4.0,
#   'categories': 'American (New), Restaurants, Steakhouses, Seafood',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Walgreens',
#   'address': '3339 Las Vegas Blvd S',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1231395999,
#   'longitude': -115.170364082,
#   'stars': 4.0,
#   'categories': 'Convenience Stores, Photography Stores & Services, Cosmetics & Beauty Supply, Shopping, Food, Beauty & Spas, Drugstores',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Black Tap',
#   'address': '3355 S Las Vegas Blvd',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1226902,
#   'longitude': -115.1701939,
#   'stars': 4.0,
#   'categories': 'Nightlife, Restaurants, Chicken Wings, Burgers, Bars, Beer Bar',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': "Sloan's Ice Cream",
#   'address': '3377 S Las Vegas Blvd, Ste 2255',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1243705,
#   'longitude': -115.169416,
#   'stars': 4.0,
#   'categories': 'Juice Bars & Smoothies, Specialty Food, Ice Cream & Frozen Yogurt, Food, Candy Stores, Desserts',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Carnaval Court Bar & Grill',
#   'address': '3475 Las Vegas Blvd S',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1193098,
#   'longitude': -115.1717702,
#   'stars': 4.0,
#   'categories': 'Arts & Entertainment, Music Venues, Bars, Nightlife',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Delmonico Steakhouse',
#   'address': '3355 Las Vegas Blvd S',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.123183,
#   'longitude': -115.16919,
#   'stars': 4.0,
#   'categories': 'Steakhouses, Restaurants, Cajun/Creole',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Joes Seafood Prime Steak & Stone Crab',
#   'address': '3500 Las Vegas Blvd S, Ste R-05',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1189331996,
#   'longitude': -115.173751944,
#   'stars': 4.5,
#   'categories': 'Steakhouses, Nightlife, Wine Bars, Bars, Restaurants, Seafood',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Bouchon Bakery at the Venetian Clock Tower',
#   'address': '3355 Las Vegas Blvd S',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1209159161,
#   'longitude': -115.169275592,
#   'stars': 4.0,
#   'categories': 'Desserts, Bakeries, Food',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Searsucker',
#   'address': '3570 Las Vegas Blvd S',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1168578154,
#   'longitude': -115.174324008,
#   'stars': 4.0,
#   'categories': 'American (New), Nightlife, Comfort Food, Bars, Restaurants',
#   'whether_Food': 1,
#   'label': 11},
#  {'name': 'Breeze Daiquiri Bar',
#   'address': '3475 S Las Vegas Blvd',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'latitude': 36.1196503,
#   'longitude': -115.1714281,
#   'stars': 4.0,
#   'categories': 'Beer Bar, Cocktail Bars, Nightlife, Bars',
#   'whether_Food': 1,
#   'label': 11}]
