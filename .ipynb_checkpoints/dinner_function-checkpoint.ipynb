# %% [markdown]
# # THIS IS THE MAIN FUNCTION ( DEF DINNER) FR THE PROJECT

# %%
import json

# %%
with open('clusters.json','rb') as clusters_init:
    clusters_data = json.loads(clusters_init.read())
clusters_data
# Out:
# [[{'name': 'Subway',
#    'address': '6020 W Craig Rd, Ste 130',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.2393761045,
#    'longitude': -115.226774905,
#    'stars': 3.0,
#    'categories': 'Food, Fast Food, Restaurants, Sandwiches',
#    'listed_categories': ['food', ' fast food', ' restaurants', ' sandwiches'],
#    'label': 0},
#   {'name': 'The Perfect Scoop Ice Cream and Boba',
#    'address': '6446 N Durango Dr, Ste 140',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.2780439,
#    'longitude': -115.2871972,
#    'stars': 3.5,
#    'categories': 'Food, Bubble Tea, Ice Cream & Frozen Yogurt, Coffee & Tea',
#    'listed_categories': ['food',
#     ' bubble tea',
#     ' ice cream & frozen yogurt',
#     ' coffee & tea'],
#    'label': 0},
#   {'name': 'Bakery & Coffee',
#    'address': '2221 North Rampart Blvd',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.2019581275,
#    'longitude': -115.283237213,
#    'stars': 4.0,
#    'categories': 'Food, Bakeries, Coffee & Tea',
#    'listed_categories': ['food', ' bakeries', ' coffee & tea'],
#    'label': 0},
#   {'name': 'Strip Jerky',
#    'address': '7450 W Cheyenne Ave, Ste 102',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.2190599,
#    'longitude': -115.2588916,
#    'stars': 5.0,
#    'categories': 'Food, Specialty Food, Restaurants',
#    'listed_categories': ['food', ' specialty food', ' restaurants'],
#    'label': 0},
#   {'name': 'Cafe Rio',
#    'address': '7664 W Lake Mead Blvd',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.1965901835,
#    'longitude': -115.262122321,
#    'stars': 2.5,
#    'categories': 'Food, Mexican, Restaurants',
#    'listed_categories': ['food', ' mexican', ' restaurants'],
#    'label': 0},
#   {'name': 'Subway',
#    'address': '6020 W Craig Rd, Ste 130',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.2393761045,
#    'longitude': -115.226774905,
#    'stars': 3.0,
#    'categories': 'Food, Fast Food, Restaurants, Sandwiches',
#    'listed_categories': ['food', ' fast food', ' restaurants', ' sandwiches'],
#    'label': 0},
#   {'name': 'The Perfect Scoop Ice Cream and Boba',
#    'address': '6446 N Durango Dr, Ste 140',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.2780439,
#    'longitude': -115.2871972,
#    'stars': 3.5,
#    'categories': 'Food, Bubble Tea, Ice Cream & Frozen Yogurt, Coffee & Tea',
#    'listed_categories': ['food',
#     ' bubble tea',
#     ' ice cream & frozen yogurt',
#     ' coffee & tea'],
#    'label': 0},
#   {'name': 'Bakery & Coffee',
#    'address': '2221 North Rampart Blvd',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.2019581275,
#    'longitude': -115.283237213,
#    'stars': 4.0,
#    'categories': 'Food, Bakeries, Coffee & Tea',
#    'listed_categories': ['food', ' bakeries', ' coffee & tea'],
#    'label': 0},
#   {'name': 'Strip Jerky',
#    'address': '7450 W Cheyenne Ave, Ste 102',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.2190599,
#    'longitude': -115.2588916,
#    'stars': 5.0,
#    'categories': 'Food, Specialty Food, Restaurants',
#    'listed_categories': ['food', ' specialty food', ' restaurants'],
#    'label': 0},
#   {'name': 'Cafe Rio',
#    'address': '7664 W Lake Mead Blvd',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.1965901835,
#    'longitude': -115.262122321,
#    'stars': 2.5,
#    'categories': 'Food, Mexican, Restaurants',
#    'listed_categories': ['food', ' mexican', ' restaurants'],
#    'label': 0},
#   {'name': "Baba's Tsi-bugan Restaurant",
#    'address': '4588 N Rancho Dr, Ste 7',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.243892,
#    'longitude': -115.234956,
#    'stars': 4.0,
#    'categories': 'Food, American (New), Food Delivery Services, Filipino, Restaurants',
#    'listed_categories': ['food',
#     ' american (new)',
#     ' food delivery services',
#     ' filipino',
#     ' restaurants'],
#    'label': 0},
#   {'name': "Trader Joe's",
#    'address': '5639 Centennial Ctr Blvd',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.2635761112,
#    'longitude': -115.257379599,
#    'stars': 4.5,
#    'categories': 'Food, Health Markets, Specialty Food, Florists, Shopping, Beer, Wine & Spirits, Grocery, Flowers & Gifts, Organic Stores',
#    'listed_categories': ['food',
#     ' health markets',
#     ' specialty food',
#     ' florists',
#     ' shopping',
#     ' beer',
#     ' wine & spirits',
#     ' grocery',
#     ' flowers & gifts',
#     ' organic stores'],
#    'label': 0},
#   {'name': 'Starbucks',
#    'address': '4850 W Craig Rd',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.2405185,
#    'longitude': -115.2090955,
#    'stars': 4.0,
#    'categories': 'Food, Coffee & Tea',
#    'listed_categories': ['food', ' coffee & tea'],
#    'label': 0},
#   {'name': 'Terrible Herbst',
#    'address': '3320 Novat St',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.2204699,
#    'longitude': -115.3292958,
#    'stars': 3.0,
#    'categories': 'Food, Gas Stations, Convenience Stores, Automotive, Car Wash',
#    'listed_categories': ['food',
#     ' gas stations',
#     ' convenience stores',
#     ' automotive',
#     ' car wash'],
#    'label': 0},
#   {'name': 'Starbucks',
#    'address': '6371 N Decatur Blvd',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.27325,
#    'longitude': -115.2098505,
#    'stars': 3.0,
#    'categories': 'Food, Coffee & Tea',
#    'listed_categories': ['food', ' coffee & tea'],
#    'label': 0},
#   {'name': "Rachel's Kitchen",
#    'address': '7010 N Durango Dr, Ste 140',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.2884223309,
#    'longitude': -115.286549547,
#    'stars': 4.0,
#    'categories': 'Food, American (New), Breakfast & Brunch, Restaurants, Juice Bars & Smoothies, Sandwiches',
#    'listed_categories': ['food',
#     ' american (new)',
#     ' breakfast & brunch',
#     ' restaurants',
#     ' juice bars & smoothies',
#     ' sandwiches'],
#    'label': 0},
#   {'name': 'Cold Stone Creamery',
#    'address': '2192 N Rainbow Blvd, Ste 101',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.199364,
#    'longitude': -115.241754,
#    'stars': 4.5,
#    'categories': 'Food, Ice Cream & Frozen Yogurt',
#    'listed_categories': ['food', ' ice cream & frozen yogurt'],
#    'label': 0},
#   {'name': '7-Eleven',
#    'address': '6980 Westcliff Dr',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.1742554,
#    'longitude': -115.2505489,
#    'stars': 2.5,
#    'categories': 'Food, Convenience Stores, Grocery, Gas Stations, Automotive, Coffee & Tea',
#    'listed_categories': ['food',
#     ' convenience stores',
#     ' grocery',
#     ' gas stations',
#     ' automotive',
#     ' coffee & tea'],
#    'label': 0},
#   {'name': 'Sun City Express',
#    'address': '6050 Smoke Ranch Rd',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.2033917,
#    'longitude': -115.223106,
#    'stars': 4.5,
#    'categories': 'Food, Convenience Stores',
#    'listed_categories': ['food', ' convenience stores'],
#    'label': 0},
#   {'name': 'The Butcher Block',
#    'address': '6440 N Durango Dr',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.2778377,
#    'longitude': -115.286646,
#    'stars': 4.5,
#    'categories': 'Food, Specialty Food, Meat Shops, Butcher, Seafood Markets',
#    'listed_categories': ['food',
#     ' specialty food',
#     ' meat shops',
#     ' butcher',
#     ' seafood markets'],
#    'label': 0},
#   {'name': 'Starbucks',
#    'address': '7541 W Lake Mead Blvd, Ste 300',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.1956881295,
#    'longitude': -115.258916865,
#    'stars': 3.5,
#    'categories': 'Food, Coffee & Tea',
#    'listed_categories': ['food', ' coffee & tea'],
#    'label': 0},
#   {'name': 'Sterling Bagels',
#    'address': '2223 N Rampart Blvd',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.2003833,
#    'longitude': -115.2819373,
#    'stars': 3.5,
#    'categories': 'Food, Bakeries, Bagels',
#    'listed_categories': ['food', ' bakeries', ' bagels'],
#    'label': 0},
#   {'name': 'Town Center Grocer 102',
#    'address': '1571 N Buffalo Dr',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.1884576,
#    'longitude': -115.2605213,
#    'stars': 1.5,
#    'categories': 'Food, Grocery',
#    'listed_categories': ['food', ' grocery'],
#    'label': 0},
#   {'name': 'Village Pub & Poker',
#    'address': '2610 Regatta Dr',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.206703,
#    'longitude': -115.2683393,
#    'stars': 3.5,
#    'categories': 'Food, Bars, Arts & Entertainment, Breweries, Casinos, Nightlife, Pubs, American (Traditional), Restaurants',
#    'listed_categories': ['food',
#     ' bars',
#     ' arts & entertainment',
#     ' breweries',
#     ' casinos',
#     ' nightlife',
#     ' pubs',
#     ' american (traditional)',
#     ' restaurants'],
#    'label': 0},
#   {'name': '7-Eleven',
#    'address': '3250 N Durango Dr',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.220111,
#    'longitude': -115.2782168,
#    'stars': 4.0,
#    'categories': 'Food, Convenience Stores',
#    'listed_categories': ['food', ' convenience stores'],
#    'label': 0},
#   {'name': "Lee's Discount Liquor",
#    'address': '7752 N El Capitan Way',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.3024459607,
#    'longitude': -115.283351429,
#    'stars': 3.0,
#    'categories': 'Food, Beer, Wine & Spirits',
#    'listed_categories': ['food', ' beer', ' wine & spirits'],
#    'label': 0},
#   {'name': 'One Stop Nutrition',
#    'address': '6171 N Decatur Blvd, Ste 130',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.2711606282,
#    'longitude': -115.2072459,
#    'stars': 5.0,
#    'categories': 'Food, Specialty Food, Juice Bars & Smoothies, Health Markets, Vitamins & Supplements, Shopping',
#    'listed_categories': ['food',
#     ' specialty food',
#     ' juice bars & smoothies',
#     ' health markets',
#     ' vitamins & supplements',
#     ' shopping'],
#    'label': 0},
#   {'name': 'Quickee Burgers',
#    'address': '4371 N Rancho Dr',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.2576752,
#    'longitude': -115.2304131,
#    'stars': 2.5,
#    'categories': 'Food, Burgers, Local Flavor, Restaurants',
#    'listed_categories': ['food', ' burgers', ' local flavor', ' restaurants'],
#    'label': 0},
#   {'name': 'Starbucks',
#    'address': '10430 W Cheyenne Ave',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.2186799013,
#    'longitude': -115.324660063,
#    'stars': 3.5,
#    'categories': 'Food, Coffee & Tea',
#    'listed_categories': ['food', ' coffee & tea'],
#    'label': 0},
#   {'name': 'Elevated Juice',
#    'address': '7703 N El Capitan Way, Ste 140',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.3005326,
#    'longitude': -115.2842028,
#    'stars': 4.0,
#    'categories': 'Food, Acai Bowls, Restaurants, Coffee & Tea, Juice Bars & Smoothies, Sandwiches',
#    'listed_categories': ['food',
#     ' acai bowls',
#     ' restaurants',
#     ' coffee & tea',
#     ' juice bars & smoothies',
#     ' sandwiches'],
#    'label': 0},
#   {'name': "Dunkin' Donuts",
#    'address': '5861 W Craig Rd, Ste 101',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.2384709,
#    'longitude': -115.2245316,
#    'stars': 2.5,
#    'categories': 'Food, Coffee & Tea, Donuts',
#    'listed_categories': ['food', ' coffee & tea', ' donuts'],
#    'label': 0},
#   {'name': "Sun's Thai Food",
#    'address': '4941 W Craig Rd',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.2380092637,
#    'longitude': -115.210298607,
#    'stars': 4.5,
#    'categories': 'Food, Thai, Restaurants',
#    'listed_categories': ['food', ' thai', ' restaurants'],
#    'label': 0},
#   {'name': 'Little Dumpling',
#    'address': '6572 N Decatur Blvd, Ste 120',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.279407,
#    'longitude': -115.206454,
#    'stars': 3.0,
#    'categories': 'Food, Restaurants, Thai, Food Delivery Services, Chinese',
#    'listed_categories': ['food',
#     ' restaurants',
#     ' thai',
#     ' food delivery services',
#     ' chinese'],
#    'label': 0},
#   {'name': 'Tropical Smoothie Cafe',
#    'address': '3390 Novat St, Ste 110',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.2210195298,
#    'longitude': -115.32900095,
#    'stars': 2.5,
#    'categories': 'Food, Restaurants, Cafes, Juice Bars & Smoothies',
#    'listed_categories': ['food',
#     ' restaurants',
#     ' cafes',
#     ' juice bars & smoothies'],
#    'label': 0},
#   {'name': 'Starbucks Coffee',
#    'address': '7660 W Cheyenne Ave',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.2191781,
#    'longitude': -115.2624712,
#    'stars': 3.5,
#    'categories': 'Food, Coffee & Tea',
#    'listed_categories': ['food', ' coffee & tea'],
#    'label': 0},
#   {'name': 'U-Swirl Frozen Yogurt',
#    'address': '6592 N Decatur Blvd, Ste 100',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.2798178536,
#    'longitude': -115.205008098,
#    'stars': 4.0,
#    'categories': 'Food, Ice Cream & Frozen Yogurt',
#    'listed_categories': ['food', ' ice cream & frozen yogurt'],
#    'label': 0},
#   {'name': 'I Love Yogurt',
#    'address': '6446 N Durango Dr, Ste 140',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.2780439,
#    'longitude': -115.2871971,
#    'stars': 4.5,
#    'categories': 'Food, Arts & Entertainment, Do-It-Yourself Food, Ice Cream & Frozen Yogurt, Arcades',
#    'listed_categories': ['food',
#     ' arts & entertainment',
#     ' do-it-yourself food',
#     ' ice cream & frozen yogurt',
#     ' arcades'],
#    'label': 0},
#   {'name': 'Vegas CheeseSteaks',
#    'address': '',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.2030945,
#    'longitude': -115.2244853,
#    'stars': 3.5,
#    'categories': 'Food, Restaurants, Food Stands, Steakhouses, Food Delivery Services',
#    'listed_categories': ['food',
#     ' restaurants',
#     ' food stands',
#     ' steakhouses',
#     ' food delivery services'],
#    'label': 0},
#   {'name': 'J & J Health Foods',
#    'address': '7501 W Lake Mead Blvd',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.19518,
#    'longitude': -115.2573615,
#    'stars': 3.5,
#    'categories': 'Food, Health Markets, Specialty Food',
#    'listed_categories': ['food', ' health markets', ' specialty food'],
#    'label': 0},
#   {'name': 'Starbucks',
#    'address': '2211 N Rampart Blvd',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.2015310484,
#    'longitude': -115.283583105,
#    'stars': 4.0,
#    'categories': 'Food, Coffee & Tea',
#    'listed_categories': ['food', ' coffee & tea'],
#    'label': 0},
#   {'name': 'Vegas Market No 3',
#    'address': '6711 W Alexander Rd',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.2327235,
#    'longitude': -115.2428425,
#    'stars': 4.0,
#    'categories': 'Food, Grocery',
#    'listed_categories': ['food', ' grocery'],
#    'label': 0},
#   {'name': 'Pies Unlimited',
#    'address': '9310 Sun City Blvd, Ste 104',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.2124013,
#    'longitude': -115.302529,
#    'stars': 2.5,
#    'categories': 'Food, Bakeries, Desserts',
#    'listed_categories': ['food', ' bakeries', ' desserts'],
#    'label': 0},
#   {'name': 'Gotta Love Cheesecake',
#    'address': '5081 N Rainbow Blvd, Ste 100',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.254562,
#    'longitude': -115.2428805,
#    'stars': 4.5,
#    'categories': 'Food, Bakeries, Coffee & Tea, Desserts',
#    'listed_categories': ['food', ' bakeries', ' coffee & tea', ' desserts'],
#    'label': 0},
#   {'name': "McDonald's",
#    'address': '6595 N Decatur Blvd',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.2799072911,
#    'longitude': -115.207143748,
#    'stars': 1.5,
#    'categories': 'Food, Coffee & Tea, Restaurants, Fast Food, Burgers',
#    'listed_categories': ['food',
#     ' coffee & tea',
#     ' restaurants',
#     ' fast food',
#     ' burgers'],
#    'label': 0},
#   {'name': 'Presto Calzone Bakery',
#    'address': '7501 N Cimarron Rd, Ste 108',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.29733,
#    'longitude': -115.270268,
#    'stars': 4.5,
#    'categories': 'Food, Desserts, Restaurants, Pizza, Bakeries',
#    'listed_categories': ['food',
#     ' desserts',
#     ' restaurants',
#     ' pizza',
#     ' bakeries'],
#    'label': 0},
#   {'name': 'Thakker Ni Thali Gujarati Food In Las Vegas',
#    'address': '',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.2684007,
#    'longitude': -115.2956118,
#    'stars': 5.0,
#    'categories': 'Food, Indian, Restaurants, Food Delivery Services',
#    'listed_categories': ['food',
#     ' indian',
#     ' restaurants',
#     ' food delivery services'],
#    'label': 0},
#   {'name': 'Fresh & Easy',
#    'address': '7752 N. El Capitan Way',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.3024038,
#    'longitude': -115.2833125,
#    'stars': 4.0,
#    'categories': 'Food, Grocery, Convenience Stores, Bakeries',
#    'listed_categories': ['food',
#     ' grocery',
#     ' convenience stores',
#     ' bakeries'],
#    'label': 0},
#   {'name': 'Splash',
#    'address': "7155 Grand Montecito Pkwy, Fabulous Freddy's",
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.2910402534,
#    'longitude': -115.284736119,
#    'stars': 5.0,
#    'categories': 'Food, Juice Bars & Smoothies, Specialty Food',
#    'listed_categories': ['food', ' juice bars & smoothies', ' specialty food'],
#    'label': 0},
#   {'name': 'The Corndog Company LV',
#    'address': '',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.2684007,
#    'longitude': -115.2956118,
#    'stars': 5.0,
#    'categories': 'Food, Street Vendors, Hot Dogs, Restaurants, Food Trucks',
#    'listed_categories': ['food',
#     ' street vendors',
#     ' hot dogs',
#     ' restaurants',
#     ' food trucks'],
#    'label': 0},
#   {'name': 'Nothing Bundt Cakes',
#    'address': '5765 Centennial Center Blvd, Ste 160',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.2651118,
#    'longitude': -115.2592432,
#    'stars': 4.5,
#    'categories': 'Food, Desserts, Cupcakes, Bakeries',
#    'listed_categories': ['food', ' desserts', ' cupcakes', ' bakeries'],
#    'label': 0},
#   {'name': 'OMG Boba Tea',
#    'address': '8560 W Lake Mead Blvd',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.2003468142,
#    'longitude': -115.279765189,
#    'stars': 3.5,
#    'categories': 'Food, Juice Bars & Smoothies, Coffee & Tea, Bubble Tea',
#    'listed_categories': ['food',
#     ' juice bars & smoothies',
#     ' coffee & tea',
#     ' bubble tea'],
#    'label': 0},
#   {'name': 'Starbucks',
#    'address': '8350 W Cheyenne Ave',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.220055,
#    'longitude': -115.275441,
#    'stars': 4.0,
#    'categories': 'Food, Coffee & Tea',
#    'listed_categories': ['food', ' coffee & tea'],
#    'label': 0},
#   {'name': "Lee's Discount Liquor",
#    'address': '6690 N Durango',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.282482,
#    'longitude': -115.284216,
#    'stars': 3.5,
#    'categories': 'Food, Beer, Wine & Spirits',
#    'listed_categories': ['food', ' beer', ' wine & spirits'],
#    'label': 0},
#   {'name': 'Einstein Bros Bagels',
#    'address': '6770 N Durango Dr, Ste 140',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.2837875042,
#    'longitude': -115.287225086,
#    'stars': 3.5,
#    'categories': 'Food, Restaurants, Breakfast & Brunch, Bagels, Coffee & Tea',
#    'listed_categories': ['food',
#     ' restaurants',
#     ' breakfast & brunch',
#     ' bagels',
#     ' coffee & tea'],
#    'label': 0},
#   {'name': 'GNC',
#    'address': '7500 W Lake Mead Blvd',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.1967482255,
#    'longitude': -115.259457226,
#    'stars': 2.0,
#    'categories': 'Food, Vitamins & Supplements, Nutritionists, Health Markets, Shopping, Specialty Food, Health & Medical',
#    'listed_categories': ['food',
#     ' vitamins & supplements',
#     ' nutritionists',
#     ' health markets',
#     ' shopping',
#     ' specialty food',
#     ' health & medical'],
#    'label': 0},
#   {'name': 'Ohlala French Bistro',
#    'address': '2120 N Rampart Blvd, Ste 150',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.198736,
#    'longitude': -115.2828319,
#    'stars': 4.5,
#    'categories': 'Food, French, Sandwiches, Brasseries, Restaurants, Desserts',
#    'listed_categories': ['food',
#     ' french',
#     ' sandwiches',
#     ' brasseries',
#     ' restaurants',
#     ' desserts'],
#    'label': 0},
#   {'name': 'Einstein Bros',
#    'address': '7541 W Lake Mead Blvd',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.195608,
#    'longitude': -115.2610055,
#    'stars': 2.0,
#    'categories': 'Food, Bagels, Mexican, Restaurants',
#    'listed_categories': ['food', ' bagels', ' mexican', ' restaurants'],
#    'label': 0},
#   {'name': '7-Eleven',
#    'address': '7591 Cimarron Rd',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.2981740712,
#    'longitude': -115.270279124,
#    'stars': 2.5,
#    'categories': 'Food, Coffee & Tea, Convenience Stores',
#    'listed_categories': ['food', ' coffee & tea', ' convenience stores'],
#    'label': 0},
#   {'name': "Coco's Bakery & Restaurant",
#    'address': 'Santa Fe Station Hotel & Casino, 4959 N Rancho Dr',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.254862,
#    'longitude': -115.225858,
#    'stars': 3.0,
#    'categories': 'Food, American (Traditional), Restaurants, Cafes, Bakeries',
#    'listed_categories': ['food',
#     ' american (traditional)',
#     ' restaurants',
#     ' cafes',
#     ' bakeries'],
#    'label': 0},
#   {'name': 'Boston Creme',
#    'address': '6475 N Decatur Blvd, Ste 125',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.2769088,
#    'longitude': -115.2079082,
#    'stars': 4.0,
#    'categories': 'Food, Ice Cream & Frozen Yogurt',
#    'listed_categories': ['food', ' ice cream & frozen yogurt'],
#    'label': 0},
#   {'name': 'Subway',
#    'address': '7500 W Lake Mead Blvd, Ste 8',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.1973681,
#    'longitude': -115.2578289,
#    'stars': 3.5,
#    'categories': 'Food, Restaurants, Sandwiches, Fast Food',
#    'listed_categories': ['food', ' restaurants', ' sandwiches', ' fast food'],
#    'label': 0},
#   {'name': 'The Walking Gourmet',
#    'address': '500 N Rainbow Blvd, Ste 300',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.178071,
#    'longitude': -115.241635,
#    'stars': 4.0,
#    'categories': 'Food, Hotels & Travel, Tours',
#    'listed_categories': ['food', ' hotels & travel', ' tours'],
#    'label': 0},
#   {'name': 'Pink Box Doughnuts',
#    'address': '7531 W Lake Mead Blvd',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.195612,
#    'longitude': -115.258259,
#    'stars': 4.5,
#    'categories': 'Food, Donuts',
#    'listed_categories': ['food', ' donuts'],
#    'label': 0},
#   {'name': "Smith's Marketplace",
#    'address': '9710 W Skye Canyon Park Dr',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.3148601239,
#    'longitude': -115.313498117,
#    'stars': 4.0,
#    'categories': 'Food, Pharmacy, Traditional Clothing, Shopping, Fashion, Grocery, Home & Garden, Health & Medical, Home Decor',
#    'listed_categories': ['food',
#     ' pharmacy',
#     ' traditional clothing',
#     ' shopping',
#     ' fashion',
#     ' grocery',
#     ' home & garden',
#     ' health & medical',
#     ' home decor'],
#    'label': 0},
#   {'name': 'Cake World',
#    'address': '3211 N Tenaya Way, Ste 101',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.2198353512,
#    'longitude': -115.251677893,
#    'stars': 4.0,
#    'categories': 'Food, Bakeries, Desserts, Cupcakes',
#    'listed_categories': ['food', ' bakeries', ' desserts', ' cupcakes'],
#    'label': 0},
#   {'name': 'Shell Gas Stations',
#    'address': '7951 Vegas Dr',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.188403,
#    'longitude': -115.268737,
#    'stars': 3.5,
#    'categories': 'Food, Convenience Stores',
#    'listed_categories': ['food', ' convenience stores'],
#    'label': 0},
#   {'name': 'Vegas Bakery',
#    'address': '2041 N Jones Blvd, Ste 108',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.1968107,
#    'longitude': -115.2224115,
#    'stars': 3.5,
#    'categories': 'Food, Custom Cakes, Bakeries, Desserts',
#    'listed_categories': ['food', ' custom cakes', ' bakeries', ' desserts'],
#    'label': 0},
#   {'name': "Raising Cane's",
#    'address': '5660 Centennial Center Blvd',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.2649695,
#    'longitude': -115.2567025,
#    'stars': 4.0,
#    'categories': 'Food, American (New), Fast Food, Restaurants, American (Traditional), Chicken Wings, Chicken Shop',
#    'listed_categories': ['food',
#     ' american (new)',
#     ' fast food',
#     ' restaurants',
#     ' american (traditional)',
#     ' chicken wings',
#     ' chicken shop'],
#    'label': 0},
#   {'name': 'Smart & Final Extra',
#    'address': '1941 N Decatur Blvd',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.1942022047,
#    'longitude': -115.207612775,
#    'stars': 4.0,
#    'categories': 'Food, Department Stores, Wholesale Stores, Shopping, Grocery, Fashion',
#    'listed_categories': ['food',
#     ' department stores',
#     ' wholesale stores',
#     ' shopping',
#     ' grocery',
#     ' fashion'],
#    'label': 0},
#   {'name': 'Starbucks',
#    'address': '2120 N Rampart Blvd',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.1987171233,
#    'longitude': -115.282968892,
#    'stars': 3.0,
#    'categories': 'Food, Coffee & Tea',
#    'listed_categories': ['food', ' coffee & tea'],
#    'label': 0},
#   {'name': 'L & L Hawaiian Barbecue',
#    'address': '1900 N Buffalo Dr',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.1945097103,
#    'longitude': -115.259734243,
#    'stars': 3.5,
#    'categories': 'Food, Barbeque, Hawaiian, Restaurants',
#    'listed_categories': ['food', ' barbeque', ' hawaiian', ' restaurants'],
#    'label': 0},
#   {'name': 'Sonic Drive-In',
#    'address': '6301 W Lake Mead Blvd',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.1954279207,
#    'longitude': -115.230752982,
#    'stars': 2.0,
#    'categories': 'Food, Restaurants, Burgers, American (Traditional), Fast Food, Ice Cream & Frozen Yogurt',
#    'listed_categories': ['food',
#     ' restaurants',
#     ' burgers',
#     ' american (traditional)',
#     ' fast food',
#     ' ice cream & frozen yogurt'],
#    'label': 0},
#   {'name': 'Health Superstore',
#    'address': '848 N Rainbow Blvd, Ste 1616',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.1808477,
#    'longitude': -115.2413278,
#    'stars': 1.0,
#    'categories': 'Food, Health & Medical, Home Health Care, Grocery',
#    'listed_categories': ['food',
#     ' health & medical',
#     ' home health care',
#     ' grocery'],
#    'label': 0},
#   {'name': 'ARCO ampm',
#    'address': '2401 N Jones Blvd',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.2034477,
#    'longitude': -115.224044,
#    'stars': 2.0,
#    'categories': 'Food, Convenience Stores, Automotive, Gas Stations',
#    'listed_categories': ['food',
#     ' convenience stores',
#     ' automotive',
#     ' gas stations'],
#    'label': 0},
#   {'name': 'Mariscos El Puerto',
#    'address': '1901 N Decatur Blvd',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.1938489978,
#    'longitude': -115.206367508,
#    'stars': 4.5,
#    'categories': 'Food, Restaurants, Specialty Food, Seafood Markets, Seafood, Mexican',
#    'listed_categories': ['food',
#     ' restaurants',
#     ' specialty food',
#     ' seafood markets',
#     ' seafood',
#     ' mexican'],
#    'label': 0},
#   {'name': 'Baskin-Robbins',
#    'address': '6454 Sky Pointe Dr, Suite 110',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.2810681,
#    'longitude': -115.2613934,
#    'stars': 2.5,
#    'categories': 'Food, Custom Cakes, Ice Cream & Frozen Yogurt, Desserts',
#    'listed_categories': ['food',
#     ' custom cakes',
#     ' ice cream & frozen yogurt',
#     ' desserts'],
#    'label': 0},
#   {'name': 'Dairy Queen',
#    'address': '1910 Village Ctr Cir, Ste 9',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.1930544975,
#    'longitude': -115.304281734,
#    'stars': 3.0,
#    'categories': 'Food, Ice Cream & Frozen Yogurt',
#    'listed_categories': ['food', ' ice cream & frozen yogurt'],
#    'label': 0},
#   {'name': "Lee's Discount Liquor",
#    'address': '7411 W Lake Mead Blvd',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.1953703,
#    'longitude': -115.2548139,
#    'stars': 3.5,
#    'categories': 'Food, Beer, Wine & Spirits',
#    'listed_categories': ['food', ' beer', ' wine & spirits'],
#    'label': 0},
#   {'name': 'City Stop Vii',
#    'address': '7591 N Cimarron Rd',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.2981896,
#    'longitude': -115.2700443,
#    'stars': 4.5,
#    'categories': 'Food, Convenience Stores',
#    'listed_categories': ['food', ' convenience stores'],
#    'label': 0},
#   {'name': 'Starbucks',
#    'address': '7101 W Craig Rd, Ste 1',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.2401358745,
#    'longitude': -115.248802305,
#    'stars': 3.5,
#    'categories': 'Food, Coffee & Tea',
#    'listed_categories': ['food', ' coffee & tea'],
#    'label': 0},
#   {'name': 'Texaco Short Line Express Market',
#    'address': '6390 N Durango Dr',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.276911,
#    'longitude': -115.287141,
#    'stars': 1.0,
#    'categories': 'Food, Gas Stations, Convenience Stores, Automotive',
#    'listed_categories': ['food',
#     ' gas stations',
#     ' convenience stores',
#     ' automotive'],
#    'label': 0},
#   {'name': '7-Eleven',
#    'address': '1200 N Town Ctr',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.1833404,
#    'longitude': -115.309844613,
#    'stars': 3.0,
#    'categories': 'Food, Coffee & Tea, Convenience Stores',
#    'listed_categories': ['food', ' coffee & tea', ' convenience stores'],
#    'label': 0},
#   {'name': 'Green Valley Grocery',
#    'address': '8390 N Decatur Blvd',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.313182,
#    'longitude': -115.206659,
#    'stars': 3.5,
#    'categories': 'Food, Grocery, Convenience Stores',
#    'listed_categories': ['food', ' grocery', ' convenience stores'],
#    'label': 0},
#   {'name': 'IHOP',
#    'address': '9651 Trailwood Dr',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.1910583,
#    'longitude': -115.30626,
#    'stars': 2.5,
#    'categories': 'Food, Breakfast & Brunch, Coffee & Tea, American (New), American (Traditional), Restaurants, Burgers',
#    'listed_categories': ['food',
#     ' breakfast & brunch',
#     ' coffee & tea',
#     ' american (new)',
#     ' american (traditional)',
#     ' restaurants',
#     ' burgers'],
#    'label': 0},
#   {'name': 'Vons',
#    'address': '1940 Village Center Cir',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.1932941,
#    'longitude': -115.3058225,
#    'stars': 3.0,
#    'categories': 'Food, Bakeries, Grocery',
#    'listed_categories': ['food', ' bakeries', ' grocery'],
#    'label': 0},
#   {'name': "Juice 'n' Go Express",
#    'address': '7155 Grand Montecito Pkwy',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.2909986365,
#    'longitude': -115.284734443,
#    'stars': 4.5,
#    'categories': 'Food, Juice Bars & Smoothies',
#    'listed_categories': ['food', ' juice bars & smoothies'],
#    'label': 0},
#   {'name': 'Organic Rumba-Fit',
#    'address': '2013 N Decatur Blvd',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.1974835272,
#    'longitude': -115.206392817,
#    'stars': 4.0,
#    'categories': 'Food, Juice Bars & Smoothies',
#    'listed_categories': ['food', ' juice bars & smoothies'],
#    'label': 0},
#   {'name': '7-Eleven',
#    'address': '3970 N Tenaya Way',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.2327416961,
#    'longitude': -115.250689611,
#    'stars': 4.0,
#    'categories': 'Food, Convenience Stores, Coffee & Tea',
#    'listed_categories': ['food', ' convenience stores', ' coffee & tea'],
#    'label': 0},
#   {'name': 'Starbucks',
#    'address': '3210 N Tenaya Way',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.219013,
#    'longitude': -115.249456,
#    'stars': 3.0,
#    'categories': 'Food, Coffee & Tea',
#    'listed_categories': ['food', ' coffee & tea'],
#    'label': 0},
#   {'name': 'Walgreens',
#    'address': '8500 W Cheyenne Ave',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.2191034,
#    'longitude': -115.279406,
#    'stars': 2.0,
#    'categories': 'Food, Shopping, Beauty & Spas, Drugstores, Cosmetics & Beauty Supply, Convenience Stores, Photography Stores & Services',
#    'listed_categories': ['food',
#     ' shopping',
#     ' beauty & spas',
#     ' drugstores',
#     ' cosmetics & beauty supply',
#     ' convenience stores',
#     ' photography stores & services'],
#    'label': 0},
#   {'name': 'Worlds Best Corndogs',
#    'address': '',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.4303079,
#    'longitude': -115.5207358,
#    'stars': 4.5,
#    'categories': 'Food, Food Trucks, Street Vendors, Restaurants, Event Planning & Services, Hot Dogs, Caterers',
#    'listed_categories': ['food',
#     ' food trucks',
#     ' street vendors',
#     ' restaurants',
#     ' event planning & services',
#     ' hot dogs',
#     ' caterers'],
#    'label': 0},
#   {'name': 'Einstein Bros Bagels',
#    'address': '1990 Village Center Cir, Ste 2',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.1918793785,
#    'longitude': -115.305118576,
#    'stars': 2.5,
#    'categories': 'Food, Bagels, Sandwiches, Restaurants',
#    'listed_categories': ['food', ' bagels', ' sandwiches', ' restaurants'],
#    'label': 0},
#   {'name': 'Pure Health Foods',
#    'address': '7575 W Washington Ave, Ste 129',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.1805335,
#    'longitude': -115.2577339,
#    'stars': 5.0,
#    'categories': 'Food, Health Markets, Nutritionists, Health & Medical, Vitamins & Supplements, Herbs & Spices, Specialty Food, Shopping',
#    'listed_categories': ['food',
#     ' health markets',
#     ' nutritionists',
#     ' health & medical',
#     ' vitamins & supplements',
#     ' herbs & spices',
#     ' specialty food',
#     ' shopping'],
#    'label': 0},
#   {'name': 'Thai Noodles Cafe',
#    'address': '6710 W Cheyenne Ave',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.2191107992,
#    'longitude': -115.242880813,
#    'stars': 4.0,
#    'categories': 'Food, Thai, Restaurants',
#    'listed_categories': ['food', ' thai', ' restaurants'],
#    'label': 0},
#   {'name': 'Albertsons',
#    'address': '1940 Village Center Cir',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.1933352771,
#    'longitude': -115.305697232,
#    'stars': 2.5,
#    'categories': 'Food, Grocery',
#    'listed_categories': ['food', ' grocery'],
#    'label': 0},
#   {'name': "Prima's Sweet Shop",
#    'address': '',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.2330997,
#    'longitude': -115.2719048,
#    'stars': 5.0,
#    'categories': 'Food, Event Planning & Services, Party & Event Planning, Bakeries',
#    'listed_categories': ['food',
#     ' event planning & services',
#     ' party & event planning',
#     ' bakeries'],
#    'label': 0},
#   {'name': 'H & H Discount Liquors',
#    'address': '1916 N Decatur Blvd',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.1945717243,
#    'longitude': -115.205167377,
#    'stars': 4.0,
#    'categories': 'Food, Beer, Wine & Spirits',
#    'listed_categories': ['food', ' beer', ' wine & spirits'],
#    'label': 0},
#   {'name': 'Starbucks',
#    'address': '1990 Village Center Cir',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.1917842025,
#    'longitude': -115.305014335,
#    'stars': 4.0,
#    'categories': 'Food, Coffee & Tea',
#    'listed_categories': ['food', ' coffee & tea'],
#    'label': 0},
#   {'name': 'Walmart Supercenter',
#    'address': '8060 W Tropical Pkwy',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.2719749798,
#    'longitude': -115.27048647,
#    'stars': 2.5,
#    'categories': 'Food, Mobile Phones, Shopping, Fashion, Department Stores, Grocery, Electronics',
#    'listed_categories': ['food',
#     ' mobile phones',
#     ' shopping',
#     ' fashion',
#     ' department stores',
#     ' grocery',
#     ' electronics'],
#    'label': 0},
#   {'name': 'German Bread Bakery',
#    'address': '2237 N Rampart Blvd',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.202011,
#    'longitude': -115.282528,
#    'stars': 4.5,
#    'categories': 'Food, Restaurants, Bakeries, German, Desserts, Pretzels',
#    'listed_categories': ['food',
#     ' restaurants',
#     ' bakeries',
#     ' german',
#     ' desserts',
#     ' pretzels'],
#    'label': 0},
#   {'name': 'Walgreens',
#    'address': '6825 N Durango Dr',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.2849842,
#    'longitude': -115.288546,
#    'stars': 2.0,
#    'categories': 'Food, Shopping, Convenience Stores, Beauty & Spas, Drugstores, Photography Stores & Services, Cosmetics & Beauty Supply',
#    'listed_categories': ['food',
#     ' shopping',
#     ' convenience stores',
#     ' beauty & spas',
#     ' drugstores',
#     ' photography stores & services',
#     ' cosmetics & beauty supply'],
#    'label': 0},
#   {'name': 'Whole Foods Market',
#    'address': '7250 W Lake Mead Blvd',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.1974857,
#    'longitude': -115.2501812,
#    'stars': 3.5,
#    'categories': 'Food, Organic Stores, Grocery, Health Markets, Specialty Food',
#    'listed_categories': ['food',
#     ' organic stores',
#     ' grocery',
#     ' health markets',
#     ' specialty food'],
#    'label': 0},
#   {'name': 'Albertsons',
#    'address': '4850 W Craig Rd',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.2405185,
#    'longitude': -115.2090955,
#    'stars': 2.5,
#    'categories': 'Food, Grocery, Drugstores, Shopping',
#    'listed_categories': ['food', ' grocery', ' drugstores', ' shopping'],
#    'label': 0},
#   {'name': "Carl's Jr",
#    'address': '7598 Vegas Dr',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.1891373,
#    'longitude': -115.2596473,
#    'stars': 3.0,
#    'categories': 'Food, Restaurants, Fast Food, Desserts, Mexican',
#    'listed_categories': ['food',
#     ' restaurants',
#     ' fast food',
#     ' desserts',
#     ' mexican'],
#    'label': 0},
#   {'name': 'Starbucks',
#    'address': '7170 N Durango Dr, Ste 110',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.2911043866,
#    'longitude': -115.287403639,
#    'stars': 3.0,
#    'categories': 'Food, Coffee & Tea',
#    'listed_categories': ['food', ' coffee & tea'],
#    'label': 0},
#   {'name': 'Chill Haus',
#    'address': '6446 N Durango Dr, Ste 140',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.2780439,
#    'longitude': -115.2871972,
#    'stars': 4.5,
#    'categories': 'Food, Ice Cream & Frozen Yogurt, Coffee & Tea, Bubble Tea',
#    'listed_categories': ['food',
#     ' ice cream & frozen yogurt',
#     ' coffee & tea',
#     ' bubble tea'],
#    'label': 0},
#   {'name': 'Retro Bakery',
#    'address': '7785 N Durango Dr, Ste 130',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.3028626327,
#    'longitude': -115.282169534,
#    'stars': 4.5,
#    'categories': 'Food, Bakeries, Desserts',
#    'listed_categories': ['food', ' bakeries', ' desserts'],
#    'label': 0},
#   {'name': 'Starbucks',
#    'address': '8410 Farm Rd',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.3003739,
#    'longitude': -115.279397,
#    'stars': 3.5,
#    'categories': 'Food, Coffee & Tea',
#    'listed_categories': ['food', ' coffee & tea'],
#    'label': 0},
#   {'name': 'Starbucks',
#    'address': '7220 W Azure Dr',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.2737499,
#    'longitude': -115.2519468,
#    'stars': 3.0,
#    'categories': 'Food, Coffee & Tea',
#    'listed_categories': ['food', ' coffee & tea'],
#    'label': 0},
#   {'name': 'Bover',
#    'address': '1780 N Buffalo Dr, Ste 107',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.1915274,
#    'longitude': -115.2594518,
#    'stars': 5.0,
#    'categories': 'Food, Juice Bars & Smoothies, Desserts, Bubble Tea, Ice Cream & Frozen Yogurt',
#    'listed_categories': ['food',
#     ' juice bars & smoothies',
#     ' desserts',
#     ' bubble tea',
#     ' ice cream & frozen yogurt'],
#    'label': 0},
#   {'name': 'Las Vegas Farmers Market',
#    'address': '9200 Tule Springs Rd',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.3230742797,
#    'longitude': -115.269716829,
#    'stars': 3.5,
#    'categories': 'Food, Farmers Market',
#    'listed_categories': ['food', ' farmers market'],
#    'label': 0},
#   {'name': "McDonald's",
#    'address': '1980 Village Ctr',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.1918348,
#    'longitude': -115.3059367,
#    'stars': 1.5,
#    'categories': 'Food, Coffee & Tea, Restaurants, Fast Food, Burgers',
#    'listed_categories': ['food',
#     ' coffee & tea',
#     ' restaurants',
#     ' fast food',
#     ' burgers'],
#    'label': 0},
#   {'name': 'Yogurtland',
#    'address': '5635 Centennial Center Blvd, Ste 120',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.2636485832,
#    'longitude': -115.257175396,
#    'stars': 4.0,
#    'categories': 'Food, Ice Cream & Frozen Yogurt',
#    'listed_categories': ['food', ' ice cream & frozen yogurt'],
#    'label': 0},
#   {'name': 'ampm',
#    'address': '7251 W Azure Dr',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.272953,
#    'longitude': -115.251887,
#    'stars': 1.5,
#    'categories': 'Food, Convenience Stores',
#    'listed_categories': ['food', ' convenience stores'],
#    'label': 0},
#   {'name': "Menchie's Frozen Yogurt",
#    'address': '7500 W Lake Mead Blvd, Ste 2',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.1962373,
#    'longitude': -115.2575104,
#    'stars': 4.0,
#    'categories': 'Food, Ice Cream & Frozen Yogurt',
#    'listed_categories': ['food', ' ice cream & frozen yogurt'],
#    'label': 0},
#   {'name': "Al's Donuts & Cafe Burger",
#    'address': '7280 W Azure Dr',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.2744266072,
#    'longitude': -115.253620172,
#    'stars': 3.0,
#    'categories': 'Food, Burgers, Restaurants, Donuts',
#    'listed_categories': ['food', ' burgers', ' restaurants', ' donuts'],
#    'label': 0},
#   {'name': 'Vegas Discount Nutrition SUPERSTORE',
#    'address': '6180 N Decatur Blvd, Ste 104',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.2723430428,
#    'longitude': -115.206228061,
#    'stars': 5.0,
#    'categories': 'Food, Specialty Food, Health Markets, Shopping, Vitamins & Supplements',
#    'listed_categories': ['food',
#     ' specialty food',
#     ' health markets',
#     ' shopping',
#     ' vitamins & supplements'],
#    'label': 0},
#   {'name': 'Juices Wild',
#    'address': '7500 W Lake Mead Blvd, Ste 8',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.1974376,
#    'longitude': -115.257775,
#    'stars': 4.5,
#    'categories': 'Food, Juice Bars & Smoothies',
#    'listed_categories': ['food', ' juice bars & smoothies'],
#    'label': 0},
#   {'name': 'Hunt & Gather Cafe',
#    'address': '7240 W Azure Dr, Ste 145',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.2745727,
#    'longitude': -115.2531,
#    'stars': 4.0,
#    'categories': 'Food, Restaurants, Cafes, Pizza, Coffee & Tea',
#    'listed_categories': ['food',
#     ' restaurants',
#     ' cafes',
#     ' pizza',
#     ' coffee & tea'],
#    'label': 0}],
#  [{'name': 'Total Wine & More',
#    'address': '6885 S Las Vegas Blvd',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.0649369,
#    'longitude': -115.17313,
#    'stars': 4.0,
#    'categories': 'Food, Tobacco Shops, Shopping, Head Shops, Beer, Wine & Spirits',
#    'listed_categories': ['food',
#     ' tobacco shops',
#     ' shopping',
#     ' head shops',
#     ' beer',
#     ' wine & spirits'],
#    'label': 1},
#   {'name': 'La Tapatia Market',
#    'address': '8826 S Eastern Ave, Ste 100',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.0291100543,
#    'longitude': -115.116823465,
#    'stars': 5.0,
#    'categories': 'Food, Meat Shops, Grocery, Seafood Markets, Fruits & Veggies, Butcher, Specialty Food',
#    'listed_categories': ['food',
#     ' meat shops',
#     ' grocery',
#     ' seafood markets',
#     ' fruits & veggies',
#     ' butcher',
#     ' specialty food'],
#    'label': 1},
#   {'name': 'Froggies Snow Cone Shack',
#    'address': '8150 Maryland Pkwy',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.0416367209,
#    'longitude': -115.135917775,
#    'stars': 5.0,
#    'categories': 'Food, Desserts, Shaved Ice',
#    'listed_categories': ['food', ' desserts', ' shaved ice'],
#    'label': 1},
#   {'name': 'Krispy Kreme',
#    'address': '9791 S Eastern Ave',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.0116514,
#    'longitude': -115.1193693,
#    'stars': 3.5,
#    'categories': 'Food, Coffee & Tea, Donuts',
#    'listed_categories': ['food', ' coffee & tea', ' donuts'],
#    'label': 1},
#   {'name': 'Total Wine & More',
#    'address': '6885 S Las Vegas Blvd',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.0649369,
#    'longitude': -115.17313,
#    'stars': 4.0,
#    'categories': 'Food, Tobacco Shops, Shopping, Head Shops, Beer, Wine & Spirits',
#    'listed_categories': ['food',
#     ' tobacco shops',
#     ' shopping',
#     ' head shops',
#     ' beer',
#     ' wine & spirits'],
#    'label': 1},
#   {'name': 'La Tapatia Market',
#    'address': '8826 S Eastern Ave, Ste 100',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.0291100543,
#    'longitude': -115.116823465,
#    'stars': 5.0,
#    'categories': 'Food, Meat Shops, Grocery, Seafood Markets, Fruits & Veggies, Butcher, Specialty Food',
#    'listed_categories': ['food',
#     ' meat shops',
#     ' grocery',
#     ' seafood markets',
#     ' fruits & veggies',
#     ' butcher',
#     ' specialty food'],
#    'label': 1},
#   {'name': 'Froggies Snow Cone Shack',
#    'address': '8150 Maryland Pkwy',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.0416367209,
#    'longitude': -115.135917775,
#    'stars': 5.0,
#    'categories': 'Food, Desserts, Shaved Ice',
#    'listed_categories': ['food', ' desserts', ' shaved ice'],
#    'label': 1},
#   {'name': 'Krispy Kreme',
#    'address': '9791 S Eastern Ave',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.0116514,
#    'longitude': -115.1193693,
#    'stars': 3.5,
#    'categories': 'Food, Coffee & Tea, Donuts',
#    'listed_categories': ['food', ' coffee & tea', ' donuts'],
#    'label': 1},
#   {'name': 'Table Thai Bar & Bistro',
#    'address': '3130 E Sunset Rd',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.0719462,
#    'longitude': -115.1069016,
#    'stars': 4.5,
#    'categories': 'Food, Beer, Wine & Spirits, Restaurants, Thai, Vegan',
#    'listed_categories': ['food',
#     ' beer',
#     ' wine & spirits',
#     ' restaurants',
#     ' thai',
#     ' vegan'],
#    'label': 1},
#   {'name': 'Dragon Grille',
#    'address': '',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.0765176,
#    'longitude': -115.1533426,
#    'stars': 4.0,
#    'categories': 'Food, Restaurants, Asian Fusion, Food Trucks',
#    'listed_categories': ['food',
#     ' restaurants',
#     ' asian fusion',
#     ' food trucks'],
#    'label': 1},
#   {'name': 'Starbucks',
#    'address': '5757 Wayne Newton Blvd',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.0838389,
#    'longitude': -115.148385,
#    'stars': 2.5,
#    'categories': 'Food, Coffee & Tea',
#    'listed_categories': ['food', ' coffee & tea'],
#    'label': 1},
#   {'name': "Lee's Liquours",
#    'address': '8180 S Maryland Pkwy',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.0411685,
#    'longitude': -115.1357786,
#    'stars': 1.0,
#    'categories': 'Food, Beer, Wine & Spirits',
#    'listed_categories': ['food', ' beer', ' wine & spirits'],
#    'label': 1},
#   {'name': 'World Beverage Company',
#    'address': '7475 S Eastern Ave',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.0539064905,
#    'longitude': -115.118639105,
#    'stars': 3.5,
#    'categories': 'Food, Beer, Wine & Spirits',
#    'listed_categories': ['food', ' beer', ' wine & spirits'],
#    'label': 1},
#   {'name': 'The Coffee Bean & Tea Leaf',
#    'address': '6599 Las Vegas Blvd S, Ste 8149',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.068142934,
#    'longitude': -115.177272074,
#    'stars': 3.5,
#    'categories': 'Food, Coffee & Tea',
#    'listed_categories': ['food', ' coffee & tea'],
#    'label': 1},
#   {'name': 'Starbucks',
#    'address': '5757 Paradise Rd',
#    'city': 'Las Vegas',
#    'state': 'NV',
# ...
#    'stars': 4.0,
#    'categories': 'Food, Breakfast & Brunch, Desserts, Japanese, Restaurants, Sushi Bars',
#    'listed_categories': ['food',
#     ' breakfast & brunch',
#     ' desserts',
#     ' japanese',
#     ' restaurants',
#     ' sushi bars'],
#    'label': 4},
#   {'name': "Smith's Food & Drug Centers",
#    'address': '6150 W Flamingo Rd',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.1157147,
#    'longitude': -115.2265196,
#    'stars': 2.0,
#    'categories': 'Food, Grocery',
#    'listed_categories': ['food', ' grocery'],
#    'label': 4},
#   {'name': 'Meet Fresh',
#    'address': '3930 Spring Mountain Rd',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.1267173,
#    'longitude': -115.1931626,
#    'stars': 4.0,
#    'categories': 'Food, Shaved Ice, Desserts, Bubble Tea',
#    'listed_categories': ['food', ' shaved ice', ' desserts', ' bubble tea'],
#    'label': 4},
#   {'name': 'Western Oriental Super Market',
#    'address': '3899 Spring Mountain Rd',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.1263711,
#    'longitude': -115.1917692,
#    'stars': 2.5,
#    'categories': 'Food, Grocery',
#    'listed_categories': ['food', ' grocery'],
#    'label': 4},
#   {'name': 'Sky Top Vending',
#    'address': '1509 Western Ave',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.1535246,
#    'longitude': -115.1603372,
#    'stars': 3.0,
#    'categories': 'Food, Local Services',
#    'listed_categories': ['food', ' local services'],
#    'label': 4},
#   {'name': 'Ice Pan',
#    'address': '3475 Las Vegas Blvd S, Fl 2',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.1193098,
#    'longitude': -115.1717702,
#    'stars': 4.5,
#    'categories': 'Food, Ice Cream & Frozen Yogurt',
#    'listed_categories': ['food', ' ice cream & frozen yogurt'],
#    'label': 4},
#   {'name': 'T & T Ginseng',
#    'address': '4115 Spring Mountain Rd',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.1260097,
#    'longitude': -115.1951608,
#    'stars': 4.0,
#    'categories': 'Food, Specialty Food, Health Markets',
#    'listed_categories': ['food', ' specialty food', ' health markets'],
#    'label': 4},
#   {'name': 'Tom Jones Food Mart & Chevron',
#    'address': '3201 W Tropicana Ave',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.1002799,
#    'longitude': -115.1834479,
#    'stars': 3.5,
#    'categories': 'Food, Gas Stations, Automotive, Convenience Stores',
#    'listed_categories': ['food',
#     ' gas stations',
#     ' automotive',
#     ' convenience stores'],
#    'label': 4},
#   {'name': 'Superior Nutrition',
#    'address': '',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.1104125,
#    'longitude': -115.2067011,
#    'stars': 5.0,
#    'categories': 'Food, Food Delivery Services',
#    'listed_categories': ['food', ' food delivery services'],
#    'label': 4},
#   {'name': 'Starbucks',
#    'address': '2530 S Decatur Blvd',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.144023909,
#    'longitude': -115.207057253,
#    'stars': 3.0,
#    'categories': 'Food, Coffee & Tea',
#    'listed_categories': ['food', ' coffee & tea'],
#    'label': 4},
#   {'name': 'Café Presse',
#    'address': '3327 Las Vegas Blvd S',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.1240615,
#    'longitude': -115.167872,
#    'stars': 3.0,
#    'categories': 'Food, Coffee & Tea',
#    'listed_categories': ['food', ' coffee & tea'],
#    'label': 4},
#   {'name': 'Liquor De Xo',
#    'address': '3850 W Desert Inn Rd, Ste 101',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.1306077,
#    'longitude': -115.1909076,
#    'stars': 4.5,
#    'categories': 'Food, Beer, Wine & Spirits',
#    'listed_categories': ['food', ' beer', ' wine & spirits'],
#    'label': 4},
#   {'name': 'Bosa Boba Cafe',
#    'address': '3711 S Valley View, Unit I',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.122364,
#    'longitude': -115.1908149,
#    'stars': 5.0,
#    'categories': 'Food, Vietnamese, Coffee & Tea, Restaurants, Bubble Tea, Sandwiches',
#    'listed_categories': ['food',
#     ' vietnamese',
#     ' coffee & tea',
#     ' restaurants',
#     ' bubble tea',
#     ' sandwiches'],
#    'label': 4},
#   {'name': "Tom Colicchio's Craftsteak",
#    'address': '3799 Las Vegas Blvd S',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.102642001,
#    'longitude': -115.168625437,
#    'stars': 4.0,
#    'categories': 'Food, Cheesesteaks, Steakhouses, Desserts, American (New), Restaurants',
#    'listed_categories': ['food',
#     ' cheesesteaks',
#     ' steakhouses',
#     ' desserts',
#     ' american (new)',
#     ' restaurants'],
#    'label': 4},
#   {'name': 'The Roasted Bean',
#    'address': '3400 S Las Vegas Blvd',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.1206533199,
#    'longitude': -115.17570137,
#    'stars': 3.0,
#    'categories': 'Food, Coffee & Tea, Bakeries, Bagels',
#    'listed_categories': ['food', ' coffee & tea', ' bakeries', ' bagels'],
#    'label': 4},
#   {'name': 'Bells Market',
#    'address': '515 E Oakey Blvd',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.1515265,
#    'longitude': -115.1511314,
#    'stars': 4.5,
#    'categories': 'Food, Convenience Stores',
#    'listed_categories': ['food', ' convenience stores'],
#    'label': 4},
#   {'name': '99 Ranch Market',
#    'address': '4155 W Spring Mountain Rd',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.1254888,
#    'longitude': -115.1952315,
#    'stars': 3.0,
#    'categories': 'Food, Grocery, Ethnic Food, Specialty Food, Seafood Markets',
#    'listed_categories': ['food',
#     ' grocery',
#     ' ethnic food',
#     ' specialty food',
#     ' seafood markets'],
#    'label': 4},
#   {'name': 'Ghirardelli Ice Cream & Chocolate Shop',
#    'address': '3545 S Las Vegas Blvd',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.1176550639,
#    'longitude': -115.16984346,
#    'stars': 4.0,
#    'categories': 'Food, Ice Cream & Frozen Yogurt, Specialty Food, Chocolatiers & Shops',
#    'listed_categories': ['food',
#     ' ice cream & frozen yogurt',
#     ' specialty food',
#     ' chocolatiers & shops'],
#    'label': 4},
#   {'name': 'Cowgirls Espresso Las Vegas',
#    'address': '4035 S Decatur Blvd',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.1166679272,
#    'longitude': -115.208192915,
#    'stars': 4.5,
#    'categories': 'Food, Coffee & Tea',
#    'listed_categories': ['food', ' coffee & tea'],
#    'label': 4},
#   {'name': 'Sprinkles Cupcakes and Ice Cream',
#    'address': '3545 S Las Vegas Blvd',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.117485,
#    'longitude': -115.169832,
#    'stars': 4.0,
#    'categories': 'Food, Cupcakes, Bakeries, Ice Cream & Frozen Yogurt',
#    'listed_categories': ['food',
#     ' cupcakes',
#     ' bakeries',
#     ' ice cream & frozen yogurt'],
#    'label': 4},
#   {'name': 'Espresso Cafe',
#    'address': '3500 Las Vegas Blvd S',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.1173432,
#    'longitude': -115.1763623,
#    'stars': 3.5,
#    'categories': 'Food, Coffee & Tea, Desserts',
#    'listed_categories': ['food', ' coffee & tea', ' desserts'],
#    'label': 4},
#   {'name': 'Hacienda Liquors',
#    'address': '5255 S Decatur Blvd',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.0944424,
#    'longitude': -115.2079863,
#    'stars': 4.5,
#    'categories': 'Food, Beer, Wine & Spirits',
#    'listed_categories': ['food', ' beer', ' wine & spirits'],
#    'label': 4},
#   {'name': "Jimmy's Seaside Fries",
#    'address': '3635 S Las Vegas Blvd, Ste 617',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.1139147095,
#    'longitude': -115.172006826,
#    'stars': 3.5,
#    'categories': 'Food, American (Traditional), Chicken Wings, Fast Food, Street Vendors, Restaurants',
#    'listed_categories': ['food',
#     ' american (traditional)',
#     ' chicken wings',
#     ' fast food',
#     ' street vendors',
#     ' restaurants'],
#    'label': 4},
#   {'name': 'Starbucks',
#    'address': '3720 S Las Vegas Blvd',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.1079837438,
#    'longitude': -115.174990717,
#    'stars': 3.0,
#    'categories': 'Food, Coffee & Tea',
#    'listed_categories': ['food', ' coffee & tea'],
#    'label': 4},
#   {'name': 'The Venetian - Food Court',
#    'address': '3355 Las Vegas Blvd',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.1229174,
#    'longitude': -115.1685253,
#    'stars': 3.5,
#    'categories': 'Food, Restaurants, Food Court',
#    'listed_categories': ['food', ' restaurants', ' food court'],
#    'label': 4},
#   {'name': '7-Eleven',
#    'address': '5700 W Charleston Blvd',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.159595,
#    'longitude': -115.219864,
#    'stars': 3.5,
#    'categories': 'Food, Grocery, Convenience Stores, Coffee & Tea',
#    'listed_categories': ['food',
#     ' grocery',
#     ' convenience stores',
#     ' coffee & tea'],
#    'label': 4},
#   {'name': 'The Cookie Dough Man',
#    'address': '4540 Arville St',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.1073108,
#    'longitude': -115.1992837,
#    'stars': 2.5,
#    'categories': 'Food, Bakeries',
#    'listed_categories': ['food', ' bakeries'],
#    'label': 4},
#   {'name': 'TBaar',
#    'address': '3743 S Las Vegas Blvd, Ste 118',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.1065515,
#    'longitude': -115.1721097,
#    'stars': 3.0,
#    'categories': 'Food, Bubble Tea, Juice Bars & Smoothies',
#    'listed_categories': ['food', ' bubble tea', ' juice bars & smoothies'],
#    'label': 4},
#   {'name': 'SF Supermarket',
#    'address': '4801 Spring Mountain Rd',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.1250739238,
#    'longitude': -115.206622348,
#    'stars': 3.5,
#    'categories': 'Food, Grocery, International Grocery',
#    'listed_categories': ['food', ' grocery', ' international grocery'],
#    'label': 4},
#   {'name': 'The Juice Standard',
#    'address': '3708 Las Vegas Blvd S',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.1099462,
#    'longitude': -115.1753911,
#    'stars': 4.0,
#    'categories': 'Food, Juice Bars & Smoothies',
#    'listed_categories': ['food', ' juice bars & smoothies'],
#    'label': 4},
#   {'name': 'Starbucks',
#    'address': '3900 Paradise Rd',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.1185522,
#    'longitude': -115.1546953,
#    'stars': 3.5,
#    'categories': 'Food, Coffee & Tea',
#    'listed_categories': ['food', ' coffee & tea'],
#    'label': 4},
#   {'name': 'Teavana',
#    'address': '3200 Las Vegas Blvd S, Ste 1795',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.1272241,
#    'longitude': -115.1715512,
#    'stars': 3.5,
#    'categories': 'Food, Coffee & Tea',
#    'listed_categories': ['food', ' coffee & tea'],
#    'label': 4},
#   {'name': "Ben's BBQ & Smokehouse",
#    'address': '',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.128561,
#    'longitude': -115.1711298,
#    'stars': 3.5,
#    'categories': 'Food, Restaurants, Food Trucks, Barbeque',
#    'listed_categories': ['food', ' restaurants', ' food trucks', ' barbeque'],
#    'label': 4},
#   {'name': "ROYCE' Las Vegas at The Grand Canal Shoppes",
#    'address': '3377 S Las Vegas Blvd',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.1218691,
#    'longitude': -115.1696529,
#    'stars': 5.0,
#    'categories': 'Food, Chocolatiers & Shops, Specialty Food, Desserts, Candy Stores',
#    'listed_categories': ['food',
#     ' chocolatiers & shops',
#     ' specialty food',
#     ' desserts',
#     ' candy stores'],
#    'label': 4},
#   {'name': 'Jamba Juice',
#    'address': '3663 Las Vegas Blvd S',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.1107323,
#    'longitude': -115.1722365,
#    'stars': 2.5,
#    'categories': 'Food, Juice Bars & Smoothies',
#    'listed_categories': ['food', ' juice bars & smoothies'],
#    'label': 4},
#   {'name': 'Strip Liquor',
#    'address': '3049 Las Vegas Blvd S, Ste 22',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.1314967,
#    'longitude': -115.1645622,
#    'stars': 4.0,
#    'categories': 'Food, Beer, Wine & Spirits',
#    'listed_categories': ['food', ' beer', ' wine & spirits'],
#    'label': 4},
#   {'name': 'America Donuts',
#    'address': '3790 S Las Vegas Blvd',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.1030009,
#    'longitude': -115.1735161,
#    'stars': 3.5,
#    'categories': 'Food, Donuts, Bakeries, Desserts',
#    'listed_categories': ['food', ' donuts', ' bakeries', ' desserts'],
#    'label': 4},
#   {'name': 'Dirt Dog - Las Vegas Strip',
#    'address': '3649 S Las Vegas Blvd, Ste 617',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.113791,
#    'longitude': -115.171633,
#    'stars': 4.5,
#    'categories': 'Food, Restaurants, Hot Dogs, Street Vendors, Desserts',
#    'listed_categories': ['food',
#     ' restaurants',
#     ' hot dogs',
#     ' street vendors',
#     ' desserts'],
#    'label': 4},
#   {'name': 'Good 2 Go Pizza',
#    'address': '3465 Las Vegas Blvd S',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.1200634014,
#    'longitude': -115.171909491,
#    'stars': 3.5,
#    'categories': 'Food, Restaurants, Pizza',
#    'listed_categories': ['food', ' restaurants', ' pizza'],
#    'label': 4},
#   {'name': 'Sofrito Rico Authentic Puerto Rican Cuisine',
#    'address': '5201 W Charleston Blvd, Ste 110',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.1588302,
#    'longitude': -115.2111651,
#    'stars': 4.5,
#    'categories': 'Food, Puerto Rican, Farmers Market, Restaurants, Latin American, Caribbean',
#    'listed_categories': ['food',
#     ' puerto rican',
#     ' farmers market',
#     ' restaurants',
#     ' latin american',
#     ' caribbean'],
#    'label': 4},
#   {'name': 'Buy Legal Meds',
#    'address': '4985 W Tropicana Ave, Ste 103',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.1003851,
#    'longitude': -115.2092021,
#    'stars': 4.5,
#    'categories': 'Food, Health & Medical, Drugstores, Pain Management, Alternative Medicine, Cannabis Clinics, Doctors, Shopping, Juice Bars & Smoothies, Cannabis Dispensaries',
#    'listed_categories': ['food',
#     ' health & medical',
#     ' drugstores',
#     ' pain management',
#     ' alternative medicine',
#     ' cannabis clinics',
#     ' doctors',
#     ' shopping',
#     ' juice bars & smoothies',
#     ' cannabis dispensaries'],
#    'label': 4},
#   {'name': 'Diamond Bakery',
#    'address': '4255 Spring Mountain Rd, Ste 110',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.1254312,
#    'longitude': -115.1969657,
#    'stars': 3.5,
#    'categories': 'Food, Bakeries',
#    'listed_categories': ['food', ' bakeries'],
#    'label': 4},
#   {'name': 'Godiva Chocolatier',
#    'address': '3200 Las Vegas Blvd S',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.127376,
#    'longitude': -115.172677,
#    'stars': 4.0,
#    'categories': 'Food, Candy Stores, Specialty Food, Chocolatiers & Shops',
#    'listed_categories': ['food',
#     ' candy stores',
#     ' specialty food',
#     ' chocolatiers & shops'],
#    'label': 4},
#   {'name': 'Liquor Outlet',
#    'address': '3999 Las Vegas Blvd S',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.09022461,
#    'longitude': -115.172292899,
#    'stars': 3.0,
#    'categories': 'Food, Beer, Wine & Spirits',
#    'listed_categories': ['food', ' beer', ' wine & spirits'],
#    'label': 4},
#   {'name': 'Mom and Pops Smoke Shop',
#    'address': '557 E Sahara Ave',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.143299,
#    'longitude': -115.148794,
#    'stars': 5.0,
#    'categories': 'Food, Grocery, Convenience Stores, Beer, Wine & Spirits',
#    'listed_categories': ['food',
#     ' grocery',
#     ' convenience stores',
#     ' beer',
#     ' wine & spirits'],
#    'label': 4},
#   {'name': 'PRESS Bar & Lounge',
#    'address': '3960 Las Vegas Blvd S',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'latitude': 36.0911164,
#    'longitude': -115.1744397,
#    'stars': 4.5,
#    'categories': 'Food, Coffee & Tea, Nightlife, Bars, Cocktail Bars, Juice Bars & Smoothies',
#    'listed_categories': ['food',
#     ' coffee & tea',
#     ' nightlife',
#     ' bars',
#     ' cocktail bars',
#     ' juice bars & smoothies'],
#    'label': 4}]]

# %%
with open('clusters_centers.json','rb') as clusters_coordinates:
    clusters_coordinates = json.loads(clusters_coordinates.read())

# %%
def dinner(person_site, radius=2):
    
    p_lati = person_site[0]
    p_long = person_site[1]
    
    
    """
    Here will be a function to determine whether the person is in Las Vegas
    """
    
    """
    For Las Vegas area, we use 1 degree latitude = 111km and 1 degree longitude = 90km
    """
    d_lati = 0.01801801801
    d_long = 0.02222222222
    
    
    k_num = len(clusters_data)
    k_distance = 100000000
    k_count = 0
    k_count_nd = 0
    k_distance_90=[]
    
    # below calculate 90 percent quantile
    for i in range(len(clusters_data)):
        k_distance_ls = []
        for rstrt in clusters_data[i]:
            k_distance_ls.append((rstrt['latitude'] - clusters_coordinates[i][0])*(rstrt['latitude'] - clusters_coordinates[i][0]) + (rstrt['longitude'] - clusters_coordinates[i][1])*(rstrt['longitude'] - clusters_coordinates[i][1]))
        k_distance_90.append(sorted(k_distance_ls)[int(0.9*len(k_distance_ls))])
    
    # below to get the closest cluster
    for i in range(k_num):
        if (p_lati - clusters_coordinates[i][0])*(p_lati - clusters_coordinates[i][0]) + (p_long - clusters_coordinates[i][1])*(p_long - clusters_coordinates[i][1]) < min(k_distance,k_distance_90[i]):
            k_distance = k_distance_90[i]
            k_count = i
    
    # below to loop over the closest cluster
    rstrt_ls=[[p_lati,p_long]]
    for rstrt in clusters_data[k_count]:
        if abs(p_lati - rstrt['latitude'])<d_lati and abs(p_long - rstrt['longitude'])<d_long:
            rstrt_ls.append(rstrt)
    
    
    if len(rstrt_ls) == 1:
        # below to get the 2nd closest cluster
        k_count_nd = 0
        for i in [elem for elem in range(k_num) if elem != k_count]:
            if (p_lati - clusters_coordinates[i][0])*(p_lati - clusters_coordinates[i][0]) + (p_long - clusters_coordinates[i][1])*(p_long - clusters_coordinates[i][1]) < min(k_distance,k_distance_90[i]):
                k_distance = k_distance_90[i]
                k_count_nd = i
        # try to loop over the 2nd closest cluster
        for rstrt in clusters_data[k_count_nd]:
            if abs(p_lati - rstrt['latitude'])<d_lati and abs(p_long - rstrt['longitude'])<d_long:
                rstrt_ls.append(rstrt)
    
    if len(rstrt_ls) != 1:
        with open('clusters_final.json', 'w') as f:
            json.dump(rstrt_ls, f)
    else:
        return("Oops, there is no such restaurant near you :(")

# %%
dinner([36.129754255580835, -115.2123383513736])

# %%
# k_distance_90=[]
# for i in range(len(clusters_data)):
#     k_distance_ls = []
#     for rstrt in clusters_data[i]:
#         k_distance_ls.append((rstrt['latitude'] - clusters_coordinates[i][0])*(rstrt['latitude'] - clusters_coordinates[i][0]) + (rstrt['longitude'] - clusters_coordinates[i][1])*(rstrt['longitude'] - clusters_coordinates[i][1]))
#     k_distance_90.append(sorted(k_distance_ls)[int(0.9*len(k_distance_ls))])

# %%
# k_distance_90
# Out:
# [0.0316686621863352,
#  0.03947588944094134,
#  0.04592910305790843,
#  0.05811040784866637,
#  8.857115519404477]
